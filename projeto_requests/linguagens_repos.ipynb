# %%
import requests

# %%
r = requests.get ('https://api.github.com/events')

# %%
print (r)
# Out:
# <Response [200]>

# %%
type (r)
# Out:
# requests.models.Response

# %%
r.status_code
# Out:
# 200

# %%
r.json ()
# Out:
# [{'id': '52746805048',
#   'type': 'CreateEvent',
#   'actor': {'id': 27028728,
#    'login': 'kjlippold',
#    'display_login': 'kjlippold',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kjlippold',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27028728?'},
#   'repo': {'id': 670755164,
#    'name': 'hydroserver2/streaming-data-loader',
#    'url': 'https://api.github.com/repos/hydroserver2/streaming-data-loader'},
#   'payload': {'ref': 'v1.3.0b4',
#    'ref_type': 'tag',
#    'master_branch': 'main',
#    'description': 'A desktop application for loading streaming data to a HydroServer instance',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-07-30T17:47:45Z',
#   'org': {'id': 120220169,
#    'login': 'hydroserver2',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/hydroserver2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/120220169?'}},
#  {'id': '52746805031',
# ...

# %%
r = requests.get ('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '["2022-11-28"]'

# %%
r = requests.get ('https://api.github.com/users/GaiasRaphael')
r.status_code
# Out:
# 200

# %%
r.json ()
# Out:
# {'login': 'GaiasRaphael',
#  'id': 168765618,
#  'node_id': 'U_kgDOCg8osg',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/168765618?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/GaiasRaphael',
#  'html_url': 'https://github.com/GaiasRaphael',
#  'followers_url': 'https://api.github.com/users/GaiasRaphael/followers',
#  'following_url': 'https://api.github.com/users/GaiasRaphael/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/GaiasRaphael/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/GaiasRaphael/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/GaiasRaphael/subscriptions',
#  'organizations_url': 'https://api.github.com/users/GaiasRaphael/orgs',
#  'repos_url': 'https://api.github.com/users/GaiasRaphael/repos',
#  'events_url': 'https://api.github.com/users/GaiasRaphael/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/GaiasRaphael/received_events',
# ...

# %%
r.url
# Out:
# 'https://api.github.com/users/GaiasRaphael'

# %%
import json

dados_user = r.json ()

print (dados_user)
# Out:
# {'login': 'GaiasRaphael', 'id': 168765618, 'node_id': 'U_kgDOCg8osg', 'avatar_url': 'https://avatars.githubusercontent.com/u/168765618?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/GaiasRaphael', 'html_url': 'https://github.com/GaiasRaphael', 'followers_url': 'https://api.github.com/users/GaiasRaphael/followers', 'following_url': 'https://api.github.com/users/GaiasRaphael/following{/other_user}', 'gists_url': 'https://api.github.com/users/GaiasRaphael/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/GaiasRaphael/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/GaiasRaphael/subscriptions', 'organizations_url': 'https://api.github.com/users/GaiasRaphael/orgs', 'repos_url': 'https://api.github.com/users/GaiasRaphael/repos', 'events_url': 'https://api.github.com/users/GaiasRaphael/events{/privacy}', 'received_events_url': 'https://api.github.com/users/GaiasRaphael/received_events', 'type': 'User', 'user_view_type': 'public', 'site_
# ...

# %%
print (dados_user['login'])
print (dados_user['name'])
print (dados_user['public_repos'])
print (dados_user['created_at'])
# Out:
# GaiasRaphael
# None
# 4
# 2024-05-02T16:59:00Z

# %%
headers = {'X-Github-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn'
url = f'{api_base_url}/users/{owner}/repos'

# %%
response = requests.get (url, headers=headers)
response.status_code
# Out:
# 200

# %%
response.json ()
# Out:
# [{'id': 171339259,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#   'name': '.github',
#   'full_name': 'amzn/.github',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
# ...

# %%
len (response.json ())
# Out:
# 30

# %%
response.url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
access_token = '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'
headers = {'Authorization': 'Bearer' + access_token, 
           'X-Github-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn'
url = f'{api_base_url}/users/{owner}/repos'

url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
repos_list = []

for page_num in range (1, 6):
    try:
        url_page = f'{url}?page={page_num}'
        response = requests.get(url_page, headers=headers)
        repos_list.append (response.json ())
    except:
        repos_list.append (None)

# %%
repos_list[0]
# Out:
# [{'id': 171339259,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#   'name': '.github',
#   'full_name': 'amzn/.github',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
# ...

# %%
len (repos_list)
# Out:
# 5

# %%
repos_name = []

for page in repos_list:
    for repo in page:
        repos_name.append (repo['name'])

repos_name
# Out:
# ['.github',
#  'ads-advanced-tools-docs',
#  'ads-pao-amznjs-gtm-server-side-template',
#  'ads-pao-amznjs-gtm-template',
#  'alexa-coho',
#  'alexa-skills-kit-js',
#  'amazon-ads-advertiser-audience-normalization-sdk-py',
#  'amazon-advertising-api-php-sdk',
#  'amazon-codeguru-profiler-for-spark',
#  'amazon-frustration-free-setup-certification-tool',
#  'amazon-hub-counter-api-docs',
#  'amazon-hub-counter-api-samples',
#  'amazon-hub-counter-sdk-java',
#  'amazon-hub-support',
#  'amazon-instant-access-sdk-java',
#  'amazon-instant-access-sdk-net',
#  'amazon-instant-access-sdk-php',
#  'amazon-instant-access-sdk-ruby',
#  'amazon-launcher-integration-cordova-plugin',
#  'amazon-marketing-stream-examples',
#  'amazon-mcf-plugin-for-magento-1',
#  'amazon-multi-token-completion',
#  'amazon-nearest-neighbor-through-ecc',
#  'amazon-pay-api-sdk-dotnet',
#  'amazon-pay-api-sdk-java',
#  'amazon-pay-api-sdk-nodejs',
#  'amazon-pay-api-sdk-php',
#  'amazon-pay-api-sdk-ruby',
# ...

# %%
len (repos_name)
# Out:
# 150

# %%
repos_list[1][1]['language']
# Out:
# 'PHP'

# %%
repos_language = []

for page in repos_list:
    for repo in page:
        repos_language.append (repo['language'])

# %%
repos_language
# Out:
# [None,
#  'Jupyter Notebook',
#  'Smarty',
#  'Smarty',
#  'JavaScript',
#  None,
#  'Python',
#  'PHP',
#  'Java',
#  'Python',
#  'CSS',
#  'Java',
#  'Java',
#  'PowerShell',
#  'Java',
#  'C#',
#  'PHP',
#  'Ruby',
#  'JavaScript',
#  'Python',
#  'PHP',
#  'Python',
#  'Jupyter Notebook',
#  'C#',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'Ruby',
#  'PHP',
#  'C#',
#  'Java',
#  'PHP',
#  'Python',
#  'Ruby',
#  'Kotlin',
#  'PHP',
#  'Python',
#  'C',
#  None,
#  'Swift',
#  'Python',
#  'C++',
#  'Python',
#  'Go',
#  'C',
#  'Python',
#  'Kotlin',
#  'Python',
#  'Python',
#  'Python',
#  None,
#  'Java',
#  'Kotlin',
#  'Python',
#  'Python',
#  'TypeScript',
#  'TypeScript',
#  'Python',
#  None,
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Java',
#  'Objective-C',
#  'JavaScript',
#  'TypeScript',
#  'Java',
#  None,
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'Java',
#  'Kotlin',
# ...

# %% [markdown]
# Criando DataFrame

# %%
import pandas as pd

# %%
dados_amz = pd.DataFrame ()
dados_amz['Name'] = repos_name
dados_amz['Language'] = repos_language

# %%
dados_amz
# Out:
#                                         Name          Language
# 0                                    .github              None
# 1                    ads-advanced-tools-docs  Jupyter Notebook
# 2    ads-pao-amznjs-gtm-server-side-template            Smarty
# 3                ads-pao-amznjs-gtm-template            Smarty
# 4                                 alexa-coho        JavaScript
# ..                                       ...               ...
# 145                               ss-aga-kgc            Python
# 146                          sto-transformer            Python
# 147      supply-chain-simulation-environment            Python
# 148               tiny-attribution-generator        TypeScript
# 149       traffic-quality-smart-pixel-loader        TypeScript
#
# [150 rows x 2 columns]

# %% [markdown]
# # Salvando DataFrame

# %%
dados_amz.to_csv ('amazon.csv')

# %%
repo_python = pd.DataFrame ()

# %%
list_python = []
for num in range (1, len (repos_language)):
    if repos_language[num] == 'Python':
        list_python.append (repos_name[num])

repo_python['Name'] = list_python

# %%
repo_python

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn'
url = f'{api_base_url}/users/{owner}/followers'

url
# Out:
# 'https://api.github.com/users/amzn/followers'

# %%
repos_list = []

for page_num in range (0, 6):
    try:
        url_page = f'{url}?page={page_num}'
        response = requests.get(url_page, headers=headers)
        repos_list.append (response.json ())
    except:
        repos_list.append (None)

# %% [markdown]
# # Criando Repositório POST

# %%
repos_list
# Out:
# [{'login': 'amzn',
#   'id': 8594673,
#   'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/amzn',
#   'html_url': 'https://github.com/amzn',
#   'followers_url': 'https://api.github.com/users/amzn/followers',
#   'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#   'organizations_url': 'https://api.github.com/users/amzn/orgs',
#   'repos_url': 'https://api.github.com/users/amzn/repos',
#   'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/amzn/received_events',
#   'type': 'Organization',
#   'user_view_type': 'public',
# ...

# %%
api_base_url = 'https://api.github.com'
url = f'{api_base_url}/user/repos'
url
# Out:
# 'https://api.github.com/user/repos'

# %%
access_token = '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'
headers = {'Authorization': f'token {access_token}', 
           'X-Github-Api-Version': '2022-11-28'}

# %%
data = {
    'name': 'linguagens-utilizadas',
    'description': 'Repositorio com as linguagens de programação da Amazon',
    'private': False
}

response = requests.post (url, json=data, headers=headers)
response.status_code
response.text
# Out:
# '{"id":1029234922,"node_id":"R_kgDOPVjg6g","name":"linguagens-utilizadas","full_name":"GaiasRaphael/linguagens-utilizadas","private":false,"owner":{"login":"GaiasRaphael","id":168765618,"node_id":"U_kgDOCg8osg","avatar_url":"https://avatars.githubusercontent.com/u/168765618?v=4","gravatar_id":"","url":"https://api.github.com/users/GaiasRaphael","html_url":"https://github.com/GaiasRaphael","followers_url":"https://api.github.com/users/GaiasRaphael/followers","following_url":"https://api.github.com/users/GaiasRaphael/following{/other_user}","gists_url":"https://api.github.com/users/GaiasRaphael/gists{/gist_id}","starred_url":"https://api.github.com/users/GaiasRaphael/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/GaiasRaphael/subscriptions","organizations_url":"https://api.github.com/users/GaiasRaphael/orgs","repos_url":"https://api.github.com/users/GaiasRaphael/repos","events_url":"https://api.github.com/users/GaiasRaphael/events{/privacy}","received_events_
# ...

# %% [markdown]
# # Formato do Arquivo

# %%
import base64

# %%
with open ('amazon.csv', 'rb') as file:
    file_content = file.read ()

encoded_content = base64.b64encode (file_content)

# %% [markdown]
# # Upload de arquivo com PUT

# %%
api_base_url = 'https://api.github.com'
username = 'GaiasRaphael'
repo = 'linguagens-utilizadas'
path = 'amazon.csv'

url = f'{api_base_url}/repos/{username}/{repo}/contents/{path}'
url
# Out:
# 'https://api.github.com/repos/GaiasRaphael/linguagens-utilizadas/contents/amazon.csv'

# %%
data = {
    'message': 'Adicionando um novo arquivo',
    'content': encoded_content.decode ('utf-8')
}

response = requests.put (url, json=data, headers=headers)
response.status_code
# Out:
# 201

# %% [markdown]
# # Fazendo um Fork

# %%
api_base_url = 'https://api.github.com'
username = 'amzn'
repo = 'pretraining-or-self-training'

url = f'{api_base_url}/repos/{username}/{repo}/forks'

headers = {'Accept': 'application/vnd.github+json',
           'Authorization': f'token {access_token}', 
           'X-Github-Api-Version': '2022-11-28'}

url
# Out:
# 'https://api.github.com/repos/amzn/pretraining-or-self-training/forks'

# %%
response = requests.post (url, headers=headers)
response.status_code
# Out:
# 202

# %%
url = 'https://api.github.com/users/amzn'

response = requests.get (url, headers=headers)

# %%
type(response.json ()['public_repos'])
# Out:
# int

# %%
import math
num = (response.json ()['public_repos']) / 30
max_page = math.ceil (num)
max_page
# Out:
# 6

# %%
for i in range (0, 5):
    print (i)
# Out:
# 0
# 1
# 2
# 3
# 4
