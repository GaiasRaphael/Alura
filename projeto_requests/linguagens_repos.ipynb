# %%
import requests

# %%
r = requests.get ('https://api.github.com/events')

# %%
print (r)
# Out:
# <Response [200]>

# %%
type (r)
# Out:
# requests.models.Response

# %%
r.status_code
# Out:
# 200

# %%
r.json ()
# Out:
# [{'id': '52644016488',
#   'type': 'PushEvent',
#   'actor': {'id': 1498203,
#    'login': 'davidmogar',
#    'display_login': 'davidmogar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/davidmogar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1498203?'},
#   'repo': {'id': 1026668878,
#    'name': 'davidmogar/e2e-base',
#    'url': 'https://api.github.com/repos/davidmogar/e2e-base'},
#   'payload': {'repository_id': 1026668878,
#    'push_id': 25777479147,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/fbc-release-6ffef457',
#    'head': '7ef700353d1e70c70469c27f12544bfc84deb04f',
#    'before': '1dbcbaf4a8472f17690aada3c5afd78dbde350ef',
#    'commits': [{'sha': 'cbd4fdf2cf64dd396bee00335302b001266c4526',
#      'author': {'email': 'konflux@no-reply.konflux-ci.dev', 'name': 'konflux'},
#      'message': 'Konflux update fbc-release-6ffef457\n\nSigned-off-by: konflux <konflux@no-reply.konflux-ci.dev>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/davidmogar/e2e-base/commits/cbd4fdf2cf64dd396bee00335302b001266c4526'},
#     {'sha': '7ef700353d1e70c70469c27f12544bfc84deb04f',
#      'author': {'email': 'david.mogar@gmail.com',
#       'name': 'David Moreno García'},
#      'message': 'pr merged by bats\n\nThis pr has been merged by bats',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/davidmogar/e2e-base/commits/7ef700353d1e70c70469c27f12544bfc84deb04f'}]},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z'},
#  {'id': '52644016481',
#   'type': 'PushEvent',
#   'actor': {'id': 9089685,
#    'login': 'rurikk94',
#    'display_login': 'rurikk94',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rurikk94',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9089685?'},
#   'repo': {'id': 907150847,
#    'name': 'rurikk94/iptv',
#    'url': 'https://api.github.com/repos/rurikk94/iptv'},
#   'payload': {'repository_id': 907150847,
#    'push_id': 25777479153,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '4e94de05f9370e2ccb2c2291673bbc263b3a5034',
#    'before': 'ad06376fe1361ed0cc95c9719881d1fb5c5e37b6',
#    'commits': [{'sha': '4e94de05f9370e2ccb2c2291673bbc263b3a5034',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'EPG Updated on Mon Jul 28 18:36:43 UTC 2025',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rurikk94/iptv/commits/4e94de05f9370e2ccb2c2291673bbc263b3a5034'}]},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z'},
#  {'id': '52644016479',
#   'type': 'PushEvent',
#   'actor': {'id': 69675754,
#    'login': 'mrantonyara',
#    'display_login': 'mrantonyara',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mrantonyara',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/69675754?'},
#   'repo': {'id': 740324611,
#    'name': 'mrantonyara/iOSWidgetUniversam',
#    'url': 'https://api.github.com/repos/mrantonyara/iOSWidgetUniversam'},
#   'payload': {'repository_id': 740324611,
#    'push_id': 25777479134,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'cbf2c224a833a936617c61b096b9ec8ba41de162',
#    'before': 'e37f076226f3d0722e0bced6e61900af759325ab',
#    'commits': [{'sha': 'cbf2c224a833a936617c61b096b9ec8ba41de162',
#      'author': {'email': '69675754+mrantonyara@users.noreply.github.com',
#       'name': 'mrantonyara'},
#      'message': 'Updated report',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mrantonyara/iOSWidgetUniversam/commits/cbf2c224a833a936617c61b096b9ec8ba41de162'}]},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z'},
#  {'id': '52644016480',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 501643739,
#    'name': 'antilt-dev/antilt-dev',
#    'url': 'https://api.github.com/repos/antilt-dev/antilt-dev'},
#   'payload': {'repository_id': 501643739,
#    'push_id': 25777479106,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '706ad4671f13007378abb35cb18b2e4494eec240',
#    'before': '266be5844a8743d077ed5faa0f41cfdecf122223',
#    'commits': [{'sha': '706ad4671f13007378abb35cb18b2e4494eec240',
#      'author': {'email': 'github-actions@github.com',
#       'name': 'github-actions'},
#      'message': 'generated',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/antilt-dev/antilt-dev/commits/706ad4671f13007378abb35cb18b2e4494eec240'}]},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z'},
#  {'id': '52644016456',
#   'type': 'PushEvent',
#   'actor': {'id': 77232170,
#    'login': 'adi224foreverg',
#    'display_login': 'adi224foreverg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/adi224foreverg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/77232170?'},
#   'repo': {'id': 437227236,
#    'name': 'adi224foreverg/globaldl',
#    'url': 'https://api.github.com/repos/adi224foreverg/globaldl'},
#   'payload': {'repository_id': 437227236,
#    'push_id': 25777479125,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'bb945b9c91b23caeff4523d584f102694b0daade',
#    'before': 'be5dc84dbc8225f63c20db358b5687e9a8da3fef',
#    'commits': [{'sha': 'bb945b9c91b23caeff4523d584f102694b0daade',
#      'author': {'email': 'storage_sdk_github@email_rand.com',
#       'name': 'storage_sdk_github'},
#      'message': 'update-2025-07-29 02:36:45',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/adi224foreverg/globaldl/commits/bb945b9c91b23caeff4523d584f102694b0daade'}]},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z'},
#  {'id': '52644016432',
#   'type': 'PushEvent',
#   'actor': {'id': 76866507,
#    'login': 'liapetronio',
#    'display_login': 'liapetronio',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/liapetronio',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/76866507?'},
#   'repo': {'id': 845774957,
#    'name': 'liapetronio/liaandkramer',
#    'url': 'https://api.github.com/repos/liapetronio/liaandkramer'},
#   'payload': {'repository_id': 845774957,
#    'push_id': 25777479143,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/demo',
#    'head': 'd91ce81af402bc97abb42bced092426963b7732d',
#    'before': '9dd7c3544a0e2d55ff424ae051bc3a1a3ec73aaa',
#    'commits': [{'sha': 'd91ce81af402bc97abb42bced092426963b7732d',
#      'author': {'email': '76866507+liapetronio@users.noreply.github.com',
#       'name': 'liapetronio'},
#      'message': 'change dist to docs',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/liapetronio/liaandkramer/commits/d91ce81af402bc97abb42bced092426963b7732d'}]},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z'},
#  {'id': '52644016477',
#   'type': 'PushEvent',
#   'actor': {'id': 6451835,
#    'login': 'brunopc-net',
#    'display_login': 'brunopc-net',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/brunopc-net',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6451835?'},
#   'repo': {'id': 692857633,
#    'name': 'brunopc-net/Horus',
#    'url': 'https://api.github.com/repos/brunopc-net/Horus'},
#   'payload': {'repository_id': 692857633,
#    'push_id': 25777479121,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': 'c427fcd0e71b07fab896ab223f53f829b2ef2c5b',
#    'before': '9249539b5c287376ca447832f2d1b204d86f0ce8',
#    'commits': [{'sha': 'c427fcd0e71b07fab896ab223f53f829b2ef2c5b',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'deploy: 69dec38139d0a2941827c938378a4fa562026cbb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/brunopc-net/Horus/commits/c427fcd0e71b07fab896ab223f53f829b2ef2c5b'}]},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z'},
#  {'id': '52644016434',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 870902319,
#    'name': 'danielraffel/ggb',
#    'url': 'https://api.github.com/repos/danielraffel/ggb'},
#   'payload': {'repository_id': 870902319,
#    'push_id': 25777479113,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '4a5b88da3e102f0be39e23d2f1ddbc0630d675fe',
#    'before': '8f4573314bdcd3c3a4e7907ee360ec33a9549df2',
#    'commits': [{'sha': '4a5b88da3e102f0be39e23d2f1ddbc0630d675fe',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Update screenshot with validated content from staging',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/danielraffel/ggb/commits/4a5b88da3e102f0be39e23d2f1ddbc0630d675fe'}]},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z'},
#  {'id': '52644016459',
#   'type': 'PushEvent',
#   'actor': {'id': 176226016,
#    'login': 'nihalsareddy',
#    'display_login': 'nihalsareddy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nihalsareddy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/176226016?'},
#   'repo': {'id': 1027884226,
#    'name': 'nihalsareddy/DocIQ',
#    'url': 'https://api.github.com/repos/nihalsareddy/DocIQ'},
#   'payload': {'repository_id': 1027884226,
#    'push_id': 25777479155,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '5d466dc28aa2700545b53feb0328da08ecc18dbf',
#    'before': '1e1581253f6397ecf839b9f3d680445e8f84740d',
#    'commits': [{'sha': '5d466dc28aa2700545b53feb0328da08ecc18dbf',
#      'author': {'email': 'nihalsareddy4@gmail.com', 'name': 'Nihal Sareddy'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nihalsareddy/DocIQ/commits/5d466dc28aa2700545b53feb0328da08ecc18dbf'}]},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z'},
#  {'id': '52644016439',
#   'type': 'PushEvent',
#   'actor': {'id': 120779766,
#    'login': 'shrey2109',
#    'display_login': 'shrey2109',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shrey2109',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/120779766?'},
#   'repo': {'id': 1027876836,
#    'name': 'shrey2109/flytbase-drone-system',
#    'url': 'https://api.github.com/repos/shrey2109/flytbase-drone-system'},
#   'payload': {'repository_id': 1027876836,
#    'push_id': 25777479114,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '511495fb13751fe08e75fdb0d1852580a1e09bee',
#    'before': '90b6a8621a15d572226743a000351a83e91b5ddd',
#    'commits': [{'sha': '511495fb13751fe08e75fdb0d1852580a1e09bee',
#      'author': {'email': 'spparikh2109@gmail.com', 'name': 'shrey2109'},
#      'message': 'fix: downgrade to React 18 to resolve leaflet-draw conflict',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shrey2109/flytbase-drone-system/commits/511495fb13751fe08e75fdb0d1852580a1e09bee'}]},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z'},
#  {'id': '52644016447',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 1010452808,
#    'name': 'yangong17/Vault',
#    'url': 'https://api.github.com/repos/yangong17/Vault'},
#   'payload': {'action': 'closed',
#    'number': 2,
#    'pull_request': {'url': 'https://api.github.com/repos/yangong17/Vault/pulls/2',
#     'id': 2664551315,
#     'node_id': 'PR_kwDOPDpJSM6e0dOT',
#     'html_url': 'https://github.com/yangong17/Vault/pull/2',
#     'diff_url': 'https://github.com/yangong17/Vault/pull/2.diff',
#     'patch_url': 'https://github.com/yangong17/Vault/pull/2.patch',
#     'issue_url': 'https://api.github.com/repos/yangong17/Vault/issues/2',
#     'number': 2,
#     'state': 'closed',
#     'locked': False,
#     'title': 'chore(deps): bump the production-dependencies group with 15 updates',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'body': "Dependabot will resolve any conflicts with this PR as long as you don't alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot show <dependency name> ignore conditions` will show all of the ignore conditions of the specified dependency\n- `@dependabot ignore <dependency name> major version` will close this group update PR and stop Dependabot creating any more for the specific dependency's major version (unless you unignore this specific dependency's major version or upgrade to it yourself)\n- `@dependabot ignore <dependency name> minor version` will close this group update PR and stop Dependabot creating any more for the specific dependency's minor version (unless you unignore this specific dependency's minor version or upgrade to it yourself)\n- `@dependabot ignore <dependency name>` will close this group update PR and stop Dependabot creating any more for the specific dependency (unless you unignore this specific dependency or upgrade to it yourself)\n- `@dependabot unignore <dependency name>` will remove all of the ignore conditions of the specified dependency\n- `@dependabot unignore <dependency name> <ignore condition>` will remove the ignore condition of the specified dependency and ignore conditions\n\n\n</details>",
#     'created_at': '2025-07-14T15:00:37Z',
#     'updated_at': '2025-07-28T18:36:46Z',
#     'closed_at': '2025-07-28T18:36:46Z',
#     'merged_at': None,
#     'merge_commit_sha': '8e6cded5238ca4fbb970af4bdda25f18f4b77a37',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 8858692315,
#       'node_id': 'LA_kwDOPDpJSM8AAAACEATq2w',
#       'url': 'https://api.github.com/repos/yangong17/Vault/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'},
#      {'id': 8942024930,
#       'node_id': 'LA_kwDOPDpJSM8AAAACFPx44g',
#       'url': 'https://api.github.com/repos/yangong17/Vault/labels/javascript',
#       'name': 'javascript',
#       'color': '168700',
#       'default': False,
#       'description': 'Pull requests that update javascript code'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/yangong17/Vault/pulls/2/commits',
#     'review_comments_url': 'https://api.github.com/repos/yangong17/Vault/pulls/2/comments',
#     'review_comment_url': 'https://api.github.com/repos/yangong17/Vault/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/yangong17/Vault/issues/2/comments',
#     'statuses_url': 'https://api.github.com/repos/yangong17/Vault/statuses/c56cbce3e5418c79c3f6c285ab34c421c89f806c',
#     'head': {'label': 'yangong17:dependabot/npm_and_yarn/production-dependencies-bdab97073a',
#      'ref': 'dependabot/npm_and_yarn/production-dependencies-bdab97073a',
#      'sha': 'c56cbce3e5418c79c3f6c285ab34c421c89f806c',
#      'user': {'login': 'yangong17',
#       'id': 96794533,
#       'node_id': 'U_kgDOBcT3pQ',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/96794533?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/yangong17',
#       'html_url': 'https://github.com/yangong17',
#       'followers_url': 'https://api.github.com/users/yangong17/followers',
#       'following_url': 'https://api.github.com/users/yangong17/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/yangong17/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/yangong17/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/yangong17/subscriptions',
#       'organizations_url': 'https://api.github.com/users/yangong17/orgs',
#       'repos_url': 'https://api.github.com/users/yangong17/repos',
#       'events_url': 'https://api.github.com/users/yangong17/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/yangong17/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 1010452808,
#       'node_id': 'R_kgDOPDpJSA',
#       'name': 'Vault',
#       'full_name': 'yangong17/Vault',
#       'private': False,
#       'owner': {'login': 'yangong17',
#        'id': 96794533,
#        'node_id': 'U_kgDOBcT3pQ',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/96794533?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/yangong17',
#        'html_url': 'https://github.com/yangong17',
#        'followers_url': 'https://api.github.com/users/yangong17/followers',
#        'following_url': 'https://api.github.com/users/yangong17/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/yangong17/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/yangong17/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/yangong17/subscriptions',
#        'organizations_url': 'https://api.github.com/users/yangong17/orgs',
#        'repos_url': 'https://api.github.com/users/yangong17/repos',
#        'events_url': 'https://api.github.com/users/yangong17/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/yangong17/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/yangong17/Vault',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/yangong17/Vault',
#       'forks_url': 'https://api.github.com/repos/yangong17/Vault/forks',
#       'keys_url': 'https://api.github.com/repos/yangong17/Vault/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/yangong17/Vault/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/yangong17/Vault/teams',
#       'hooks_url': 'https://api.github.com/repos/yangong17/Vault/hooks',
#       'issue_events_url': 'https://api.github.com/repos/yangong17/Vault/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/yangong17/Vault/events',
#       'assignees_url': 'https://api.github.com/repos/yangong17/Vault/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/yangong17/Vault/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/yangong17/Vault/tags',
#       'blobs_url': 'https://api.github.com/repos/yangong17/Vault/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/yangong17/Vault/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/yangong17/Vault/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/yangong17/Vault/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/yangong17/Vault/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/yangong17/Vault/languages',
#       'stargazers_url': 'https://api.github.com/repos/yangong17/Vault/stargazers',
#       'contributors_url': 'https://api.github.com/repos/yangong17/Vault/contributors',
#       'subscribers_url': 'https://api.github.com/repos/yangong17/Vault/subscribers',
#       'subscription_url': 'https://api.github.com/repos/yangong17/Vault/subscription',
#       'commits_url': 'https://api.github.com/repos/yangong17/Vault/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/yangong17/Vault/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/yangong17/Vault/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/yangong17/Vault/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/yangong17/Vault/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/yangong17/Vault/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/yangong17/Vault/merges',
#       'archive_url': 'https://api.github.com/repos/yangong17/Vault/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/yangong17/Vault/downloads',
#       'issues_url': 'https://api.github.com/repos/yangong17/Vault/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/yangong17/Vault/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/yangong17/Vault/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/yangong17/Vault/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/yangong17/Vault/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/yangong17/Vault/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/yangong17/Vault/deployments',
#       'created_at': '2025-06-29T05:19:50Z',
#       'updated_at': '2025-06-29T05:37:58Z',
#       'pushed_at': '2025-07-14T15:00:37Z',
#       'git_url': 'git://github.com/yangong17/Vault.git',
#       'ssh_url': 'git@github.com:yangong17/Vault.git',
#       'clone_url': 'https://github.com/yangong17/Vault.git',
#       'svn_url': 'https://github.com/yangong17/Vault',
#       'homepage': None,
#       'size': 15923,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'yangong17:main',
#      'ref': 'main',
#      'sha': 'b07fb249d9d2779210652ba3cccbd29ca6e3ccbf',
#      'user': {'login': 'yangong17',
#       'id': 96794533,
#       'node_id': 'U_kgDOBcT3pQ',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/96794533?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/yangong17',
#       'html_url': 'https://github.com/yangong17',
#       'followers_url': 'https://api.github.com/users/yangong17/followers',
#       'following_url': 'https://api.github.com/users/yangong17/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/yangong17/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/yangong17/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/yangong17/subscriptions',
#       'organizations_url': 'https://api.github.com/users/yangong17/orgs',
#       'repos_url': 'https://api.github.com/users/yangong17/repos',
#       'events_url': 'https://api.github.com/users/yangong17/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/yangong17/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 1010452808,
#       'node_id': 'R_kgDOPDpJSA',
#       'name': 'Vault',
#       'full_name': 'yangong17/Vault',
#       'private': False,
#       'owner': {'login': 'yangong17',
#        'id': 96794533,
#        'node_id': 'U_kgDOBcT3pQ',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/96794533?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/yangong17',
#        'html_url': 'https://github.com/yangong17',
#        'followers_url': 'https://api.github.com/users/yangong17/followers',
#        'following_url': 'https://api.github.com/users/yangong17/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/yangong17/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/yangong17/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/yangong17/subscriptions',
#        'organizations_url': 'https://api.github.com/users/yangong17/orgs',
#        'repos_url': 'https://api.github.com/users/yangong17/repos',
#        'events_url': 'https://api.github.com/users/yangong17/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/yangong17/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/yangong17/Vault',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/yangong17/Vault',
#       'forks_url': 'https://api.github.com/repos/yangong17/Vault/forks',
#       'keys_url': 'https://api.github.com/repos/yangong17/Vault/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/yangong17/Vault/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/yangong17/Vault/teams',
#       'hooks_url': 'https://api.github.com/repos/yangong17/Vault/hooks',
#       'issue_events_url': 'https://api.github.com/repos/yangong17/Vault/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/yangong17/Vault/events',
#       'assignees_url': 'https://api.github.com/repos/yangong17/Vault/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/yangong17/Vault/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/yangong17/Vault/tags',
#       'blobs_url': 'https://api.github.com/repos/yangong17/Vault/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/yangong17/Vault/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/yangong17/Vault/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/yangong17/Vault/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/yangong17/Vault/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/yangong17/Vault/languages',
#       'stargazers_url': 'https://api.github.com/repos/yangong17/Vault/stargazers',
#       'contributors_url': 'https://api.github.com/repos/yangong17/Vault/contributors',
#       'subscribers_url': 'https://api.github.com/repos/yangong17/Vault/subscribers',
#       'subscription_url': 'https://api.github.com/repos/yangong17/Vault/subscription',
#       'commits_url': 'https://api.github.com/repos/yangong17/Vault/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/yangong17/Vault/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/yangong17/Vault/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/yangong17/Vault/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/yangong17/Vault/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/yangong17/Vault/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/yangong17/Vault/merges',
#       'archive_url': 'https://api.github.com/repos/yangong17/Vault/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/yangong17/Vault/downloads',
#       'issues_url': 'https://api.github.com/repos/yangong17/Vault/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/yangong17/Vault/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/yangong17/Vault/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/yangong17/Vault/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/yangong17/Vault/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/yangong17/Vault/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/yangong17/Vault/deployments',
#       'created_at': '2025-06-29T05:19:50Z',
#       'updated_at': '2025-06-29T05:37:58Z',
#       'pushed_at': '2025-07-14T15:00:37Z',
#       'git_url': 'git://github.com/yangong17/Vault.git',
#       'ssh_url': 'git@github.com:yangong17/Vault.git',
#       'clone_url': 'https://github.com/yangong17/Vault.git',
#       'svn_url': 'https://github.com/yangong17/Vault',
#       'homepage': None,
#       'size': 15923,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/yangong17/Vault/pulls/2'},
#      'html': {'href': 'https://github.com/yangong17/Vault/pull/2'},
#      'issue': {'href': 'https://api.github.com/repos/yangong17/Vault/issues/2'},
#      'comments': {'href': 'https://api.github.com/repos/yangong17/Vault/issues/2/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/yangong17/Vault/pulls/2/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/yangong17/Vault/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/yangong17/Vault/pulls/2/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/yangong17/Vault/statuses/c56cbce3e5418c79c3f6c285ab34c421c89f806c'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': False,
#     'mergeable_state': 'clean',
#     'merged_by': None,
#     'comments': 1,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 458,
#     'deletions': 364,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z'},
#  {'id': '52644016433',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 503230888,
#    'name': 'mtalibfarooq/mtalibfarooq',
#    'url': 'https://api.github.com/repos/mtalibfarooq/mtalibfarooq'},
#   'payload': {'repository_id': 503230888,
#    'push_id': 25777479145,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '787063c97ad059e09c1629c994a04684cf92a253',
#    'before': 'e92f6ee8533fba995db37173a967e835b8952c56',
#    'commits': [{'sha': '787063c97ad059e09c1629c994a04684cf92a253',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mtalibfarooq/mtalibfarooq/commits/787063c97ad059e09c1629c994a04684cf92a253'}]},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z'},
#  {'id': '52644016424',
#   'type': 'PushEvent',
#   'actor': {'id': 5176469,
#    'login': 'Saleh7',
#    'display_login': 'Saleh7',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Saleh7',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5176469?'},
#   'repo': {'id': 892853621,
#    'name': 'Saleh7/BadTrafficData',
#    'url': 'https://api.github.com/repos/Saleh7/BadTrafficData'},
#   'payload': {'repository_id': 892853621,
#    'push_id': 25777479136,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': '3ec0f7017cc5c5adbe768135e51094b9f498d0bd',
#    'before': 'ee7361511c1c580768b07564252c8600c6376022',
#    'commits': [{'sha': '6734337ad1ca938987279190af7f26743d3f46b8',
#      'author': {'email': 'ipain7@gmail.com', 'name': 'Saleh7'},
#      'message': '👾 Update suspicious_user_agents_list.txt',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Saleh7/BadTrafficData/commits/6734337ad1ca938987279190af7f26743d3f46b8'},
#     {'sha': '3ec0f7017cc5c5adbe768135e51094b9f498d0bd',
#      'author': {'email': 'ipain7@gmail.com', 'name': 'Saleh7'},
#      'message': '📝 Update README.md with the latest information',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Saleh7/BadTrafficData/commits/3ec0f7017cc5c5adbe768135e51094b9f498d0bd'}]},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z'},
#  {'id': '52644016423',
#   'type': 'PushEvent',
#   'actor': {'id': 108946930,
#    'login': 'ntthuan0106',
#    'display_login': 'ntthuan0106',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ntthuan0106',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/108946930?'},
#   'repo': {'id': 980451527,
#    'name': 'ntthuan0106/opswat-training-final',
#    'url': 'https://api.github.com/repos/ntthuan0106/opswat-training-final'},
#   'payload': {'repository_id': 980451527,
#    'push_id': 25777479124,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b5d435ca34eb78fbf85b09285326bcba68966689',
#    'before': 'b5e9467aa4b4011dba294f3f135db8c42a36e8c7',
#    'commits': [{'sha': 'b5d435ca34eb78fbf85b09285326bcba68966689',
#      'author': {'email': '108946930+ntthuan0106@users.noreply.github.com',
#       'name': 'ntthuan0106'},
#      'message': 'Delete terraform-test/workspaces/prod directory',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ntthuan0106/opswat-training-final/commits/b5d435ca34eb78fbf85b09285326bcba68966689'}]},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z'},
#  {'id': '52644016436',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 673234555,
#    'name': 'amanarora001/Ammy',
#    'url': 'https://api.github.com/repos/amanarora001/Ammy'},
#   'payload': {'repository_id': 673234555,
#    'push_id': 25777479127,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '421bb77220abd968fd566a206ab641de00f62bf5',
#    'before': '278ff0438a01a8f689a580d8fcb027346ee53449',
#    'commits': [{'sha': '421bb77220abd968fd566a206ab641de00f62bf5',
#      'author': {'email': 'aroraaman201098@gmail.com', 'name': 'amanarora001'},
#      'message': 'a commit a day keeps your girlfriend away',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/amanarora001/Ammy/commits/421bb77220abd968fd566a206ab641de00f62bf5'}]},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z'},
#  {'id': '52644016399',
#   'type': 'WatchEvent',
#   'actor': {'id': 105701368,
#    'login': 'scyzp3',
#    'display_login': 'scyzp3',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/scyzp3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/105701368?'},
#   'repo': {'id': 752925682,
#    'name': 'QwenLM/Qwen3',
#    'url': 'https://api.github.com/repos/QwenLM/Qwen3'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z',
#   'org': {'id': 141221163,
#    'login': 'QwenLM',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/QwenLM',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/141221163?'}},
#  {'id': '52644016422',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 112327715,
#    'name': 'tresende/tresende.github.io',
#    'url': 'https://api.github.com/repos/tresende/tresende.github.io'},
#   'payload': {'action': 'opened',
#    'number': 1920,
#    'pull_request': {'url': 'https://api.github.com/repos/tresende/tresende.github.io/pulls/1920',
#     'id': 2701741250,
#     'node_id': 'PR_kwDOBrH8I86hCUzC',
#     'html_url': 'https://github.com/tresende/tresende.github.io/pull/1920',
#     'diff_url': 'https://github.com/tresende/tresende.github.io/pull/1920.diff',
#     'patch_url': 'https://github.com/tresende/tresende.github.io/pull/1920.patch',
#     'issue_url': 'https://api.github.com/repos/tresende/tresende.github.io/issues/1920',
#     'number': 1920,
#     'state': 'open',
#     'locked': False,
#     'title': 'chore(deps): bump next from 15.4.1 to 15.4.4',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'body': 'Bumps [next](https://github.com/vercel/next.js) from 15.4.1 to 15.4.4.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/vercel/next.js/releases">next\'s releases</a>.</em></p>\n<blockquote>\n<h2>v15.4.4</h2>\n<blockquote>\n<p>[!NOTE]<br />\nThis release is backporting bug fixes. It does <strong>not</strong> include all pending features/changes on canary.</p>\n</blockquote>\n<h3>Core Changes</h3>\n<ul>\n<li>Fix dynamicParams false layout case in dev (<a href="https://redirect.github.com/vercel/next.js/issues/82026">#82026</a>)</li>\n<li>Turbopack: fix scope hoisting variable renaming bug (<a href="https://redirect.github.com/vercel/next.js/issues/81640">#81640</a>)</li>\n<li>Upgrade to swc v33 (<a href="https://redirect.github.com/vercel/next.js/issues/81750">#81750</a>)</li>\n<li>Revert &quot;[metadata] use https protocol for schema urls&quot; (<a href="https://redirect.github.com/vercel/next.js/issues/81934">#81934</a>)</li>\n</ul>\n<h3>Credits</h3>\n<p>Huge thanks to <a href="https://github.com/bgw"><code>@\u200bbgw</code></a>  <a href="https://github.com/mischnic"><code>@\u200bmischnic</code></a> <a href="https://github.com/huozhi"><code>@\u200bhuozhi</code></a> <a href="https://github.com/lukesandberg"><code>@\u200blukesandberg</code></a> and <a href="https://github.com/ijjk"><code>@\u200bijjk</code></a> for helping!</p>\n<h2>v15.4.3</h2>\n<blockquote>\n<p>[!NOTE]<br />\nThis release is backporting bug fixes. It does <strong>not</strong> include all pending features/changes on canary.</p>\n</blockquote>\n<h3>Core Changes</h3>\n<ul>\n<li>Turbopack: fix dist dir on Windows (<a href="https://redirect.github.com/vercel/next.js/issues/81758">#81758</a>)</li>\n</ul>\n<h3>Credits</h3>\n<p>Huge thanks to <a href="https://github.com/mischnic"><code>@\u200bmischnic</code></a> for helping!</p>\n<h2>v15.4.2</h2>\n<blockquote>\n<p>[!NOTE]<br />\nThis release is backporting bug fixes. It does <strong>not</strong> include all pending features/changes on canary.</p>\n</blockquote>\n<h3>Core Changes</h3>\n<ul>\n<li>pages router metadata bugs with React 19 (<a href="https://redirect.github.com/vercel/next.js/issues/81733">#81733</a>)</li>\n<li>[metadata] replace for initial body icon case (<a href="https://redirect.github.com/vercel/next.js/issues/81688">#81688</a>)</li>\n<li>Ensure custom NextServer config is honored (<a href="https://redirect.github.com/vercel/next.js/issues/81681">#81681</a>)</li>\n</ul>\n<h3>Credits</h3>\n<p>Huge thanks to <a href="https://github.com/huozhi"><code>@\u200bhuozhi</code></a>, <a href="https://github.com/ijjk"><code>@\u200bijjk</code></a>, and <a href="https://github.com/ztanner"><code>@\u200bztanner</code></a> for helping!</p>\n<h2>v15.4.2-canary.18</h2>\n<h3>Core Changes</h3>\n<ul>\n<li>Revert &quot;Upgrade vercel og and remove yoga type patching (<a href="https://redirect.github.com/vercel/next.js/issues/81937">#81937</a>)&quot;: <a href="https://redirect.github.com/vercel/next.js/issues/82066">#82066</a></li>\n</ul>\n<!-- raw HTML omitted -->\n</blockquote>\n<p>... (truncated)</p>\n</details>\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/vercel/next.js/commit/fe5db65859f0658d1c4701635ec4f4e5ec507e64"><code>fe5db65</code></a> v15.4.4</li>\n<li><a href="https://github.com/vercel/next.js/commit/4a90ff74ca23b0b6cc557f3981bdaeb870c90151"><code>4a90ff7</code></a> [backport] Fix dynamicParams false layout case in dev (<a href="https://redirect.github.com/vercel/next.js/issues/82026">#82026</a>)</li>\n<li><a href="https://github.com/vercel/next.js/commit/9bf932c0c6a9ad460c6e79c17fa697533c550975"><code>9bf932c</code></a> Turbopack: fix scope hoisting variable renaming bug (<a href="https://redirect.github.com/vercel/next.js/issues/81640">#81640</a>)</li>\n<li><a href="https://github.com/vercel/next.js/commit/6d0ffcc752cccdd0637783ca9325cbfc2fbb84dc"><code>6d0ffcc</code></a> Upgrade to swc v33 (<a href="https://redirect.gith ...
#     'created_at': '2025-07-28T18:36:45Z',
#     'updated_at': '2025-07-28T18:36:47Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': {'login': 'tresende',
#      'id': 32820963,
#      'node_id': 'MDQ6VXNlcjMyODIwOTYz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/32820963?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/tresende',
#      'html_url': 'https://github.com/tresende',
#      'followers_url': 'https://api.github.com/users/tresende/followers',
#      'following_url': 'https://api.github.com/users/tresende/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/tresende/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/tresende/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/tresende/subscriptions',
#      'organizations_url': 'https://api.github.com/users/tresende/orgs',
#      'repos_url': 'https://api.github.com/users/tresende/repos',
#      'events_url': 'https://api.github.com/users/tresende/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/tresende/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'assignees': [{'login': 'tresende',
#       'id': 32820963,
#       'node_id': 'MDQ6VXNlcjMyODIwOTYz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/32820963?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/tresende',
#       'html_url': 'https://github.com/tresende',
#       'followers_url': 'https://api.github.com/users/tresende/followers',
#       'following_url': 'https://api.github.com/users/tresende/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/tresende/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/tresende/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/tresende/subscriptions',
#       'organizations_url': 'https://api.github.com/users/tresende/orgs',
#       'repos_url': 'https://api.github.com/users/tresende/repos',
#       'events_url': 'https://api.github.com/users/tresende/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/tresende/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False}],
#     'requested_reviewers': [{'login': 'tresende',
#       'id': 32820963,
#       'node_id': 'MDQ6VXNlcjMyODIwOTYz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/32820963?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/tresende',
#       'html_url': 'https://github.com/tresende',
#       'followers_url': 'https://api.github.com/users/tresende/followers',
#       'following_url': 'https://api.github.com/users/tresende/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/tresende/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/tresende/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/tresende/subscriptions',
#       'organizations_url': 'https://api.github.com/users/tresende/orgs',
#       'repos_url': 'https://api.github.com/users/tresende/repos',
#       'events_url': 'https://api.github.com/users/tresende/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/tresende/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False}],
#     'requested_teams': [],
#     'labels': [{'id': 1653053635,
#       'node_id': 'MDU6TGFiZWwxNjUzMDUzNjM1',
#       'url': 'https://api.github.com/repos/tresende/tresende.github.io/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/tresende/tresende.github.io/pulls/1920/commits',
#     'review_comments_url': 'https://api.github.com/repos/tresende/tresende.github.io/pulls/1920/comments',
# ...
#      'html': {'href': 'https://github.com/tresende/tresende.github.io/pull/1920'},
#      'issue': {'href': 'https://api.github.com/repos/tresende/tresende.github.io/issues/1920'},
#      'comments': {'href': 'https://api.github.com/repos/tresende/tresende.github.io/issues/1920/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/tresende/tresende.github.io/pulls/1920/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/tresende/tresende.github.io/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/tresende/tresende.github.io/pulls/1920/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/tresende/tresende.github.io/statuses/a929deba1757a37142606e42865fd3f01d34f867'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 1,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 57,
#     'deletions': 57,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z'},
#  {'id': '52644016415',
#   'type': 'CreateEvent',
#   'actor': {'id': 132502831,
#    'login': 'fsl2023',
#    'display_login': 'fsl2023',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fsl2023',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/132502831?'},
#   'repo': {'id': 1027919394,
#    'name': 'fsl2023/my-java-app2',
#    'url': 'https://api.github.com/repos/fsl2023/my-java-app2'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z'},
#  {'id': '52644016252',
#   'type': 'PushEvent',
#   'actor': {'id': 87141165,
#    'login': 'trunk-staging-io[bot]',
#    'display_login': 'trunk-staging-io',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/trunk-staging-io[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/87141165?'},
#   'repo': {'id': 1021130530,
#    'name': 'trunk-io/mergequeue-demo',
#    'url': 'https://api.github.com/repos/trunk-io/mergequeue-demo'},
#   'payload': {'repository_id': 1021130530,
#    'push_id': 25777478979,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/trunk-temp/pr-21589/cd45786d-4270-42de-8784-212c8fdd0c00',
#    'head': 'b0c7a0fa3e3d45ecc383c1d43f8df11fd4a46e58',
#    'before': '128090dc7ecb25df6035da8b7a658b7447944ac2',
#    'commits': [{'sha': 'd6b4ef7baf07cba36b14b2c121d57b0e47c4ff06',
#      'author': {'email': 'bot@trunk.io', 'name': 'trunk bot'},
#      'message': 'Moving words aural',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/trunk-io/mergequeue-demo/commits/d6b4ef7baf07cba36b14b2c121d57b0e47c4ff06'},
#     {'sha': 'b0c7a0fa3e3d45ecc383c1d43f8df11fd4a46e58',
#      'author': {'email': '87141165+trunk-staging-io[bot]@users.noreply.github.com',
#       'name': 'trunk-staging-io[bot]'},
#      'message': 'Merging d6b4ef7baf07cba36b14b2c121d57b0e47c4ff06 into trunk-temp/pr-21589/cd45786d-4270-42de-8784-212c8fdd0c00',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/trunk-io/mergequeue-demo/commits/b0c7a0fa3e3d45ecc383c1d43f8df11fd4a46e58'}]},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z',
#   'org': {'id': 74779146,
#    'login': 'trunk-io',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/trunk-io',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/74779146?'}},
#  {'id': '52644016343',
#   'type': 'PushEvent',
#   'actor': {'id': 703017,
#    'login': 'cb22',
#    'display_login': 'cb22',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cb22',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/703017?'},
#   'repo': {'id': 746930940,
#    'name': 'tigerbeetle/devhubdb',
#    'url': 'https://api.github.com/repos/tigerbeetle/devhubdb'},
#   'payload': {'repository_id': 746930940,
#    'push_id': 25777479045,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '1feef10ed5ed15d8331f2ea4bd26b30e395cd382',
#    'before': '339952b33a95bcfcca2a13bbb4df632ca8d0acc9',
#    'commits': [{'sha': '1feef10ed5ed15d8331f2ea4bd26b30e395cd382',
#      'author': {'email': 'bot@tigerbeetle.com',
#       'name': '95-216-13-232.tigerbeetle.hetzner'},
#      'message': '🌱',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tigerbeetle/devhubdb/commits/1feef10ed5ed15d8331f2ea4bd26b30e395cd382'}]},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z',
#   'org': {'id': 112812516,
#    'login': 'tigerbeetle',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/tigerbeetle',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/112812516?'}},
#  {'id': '52644016347',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 291484940,
#    'name': 'niclaslind/niclaslind',
#    'url': 'https://api.github.com/repos/niclaslind/niclaslind'},
#   'payload': {'repository_id': 291484940,
#    'push_id': 25777479109,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'fc9b0e08b52160e0d74a40ca0782b3dc979d9235',
#    'before': 'df1deccffb9afe460541c567560a0c5d182abc9f',
#    'commits': [{'sha': 'fc9b0e08b52160e0d74a40ca0782b3dc979d9235',
#      'author': {'email': 'github-actions@github.com',
#       'name': 'github-actions'},
#      'message': 'generated',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/niclaslind/niclaslind/commits/fc9b0e08b52160e0d74a40ca0782b3dc979d9235'}]},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z'},
#  {'id': '52644016342',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 749387219,
#    'name': 'NurmalaFitra/nurmalacom',
#    'url': 'https://api.github.com/repos/NurmalaFitra/nurmalacom'},
#   'payload': {'repository_id': 749387219,
#    'push_id': 25777479061,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'da50815f48cc28552bcf2fd392c41e383e46f51d',
#    'before': 'ad4b45b268ba8aee9faab79c45771da233ad90b5',
#    'commits': [{'sha': 'da50815f48cc28552bcf2fd392c41e383e46f51d',
#      'author': {'email': 'akungarap650@gmail.com', 'name': 'NurmalaFitra'},
#      'message': 'chore(bot): 🙏 auto commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/NurmalaFitra/nurmalacom/commits/da50815f48cc28552bcf2fd392c41e383e46f51d'}]},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z'},
#  {'id': '52644016330',
#   'type': 'PushEvent',
#   'actor': {'id': 66853113,
#    'login': 'pre-commit-ci[bot]',
#    'display_login': 'pre-commit-ci',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pre-commit-ci[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66853113?'},
#   'repo': {'id': 988598742,
#    'name': 'RonnyPfannschmidt/ronny-langraph',
#    'url': 'https://api.github.com/repos/RonnyPfannschmidt/ronny-langraph'},
#   'payload': {'repository_id': 988598742,
#    'push_id': 25777479096,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/pre-commit-ci-update-config',
#    'head': 'b7c3ff94a628bef99d0effb0ec9505be7dbf4d6e',
#    'before': 'fb43d1f93a650067191a4d4e72ec9726c36464da',
#    'commits': [{'sha': 'b7c3ff94a628bef99d0effb0ec9505be7dbf4d6e',
#      'author': {'email': '66853113+pre-commit-ci[bot]@users.noreply.github.com',
#       'name': 'pre-commit-ci[bot]'},
#      'message': '[pre-commit.ci] pre-commit autoupdate\n\nupdates:\n- [github.com/astral-sh/ruff-pre-commit: v0.11.9 → v0.12.5](https://github.com/astral-sh/ruff-pre-commit/compare/v0.11.9...v0.12.5)\n- [github.com/pre-commit/mirrors-mypy: v1.15.0 → v1.17.0](https://github.com/pre-commit/mirrors-mypy/compare/v1.15.0...v1.17.0)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/RonnyPfannschmidt/ronny-langraph/commits/b7c3ff94a628bef99d0effb0ec9505be7dbf4d6e'}]},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z'},
#  {'id': '52644016276',
#   'type': 'PushEvent',
#   'actor': {'id': 111416970,
#    'login': 'vlabs-bug',
#    'display_login': 'vlabs-bug',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vlabs-bug',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/111416970?'},
#   'repo': {'id': 353264692,
#    'name': 'virtual-labs/bugs-virtual-labs',
#    'url': 'https://api.github.com/repos/virtual-labs/bugs-virtual-labs'},
#   'payload': {'repository_id': 353264692,
#    'push_id': 25777478972,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '720110acc96be66d1836a5a1832c8bfe1045b3a6',
#    'before': 'b63a84305c42d4058b1a28f07402eccb1839418e',
#    'commits': [{'sha': '720110acc96be66d1836a5a1832c8bfe1045b3a6',
#      'author': {'email': '111416970+vlabs-bug@users.noreply.github.com',
#       'name': 'vlabs-bug'},
#      'message': 'Adding an image to the repository',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/virtual-labs/bugs-virtual-labs/commits/720110acc96be66d1836a5a1832c8bfe1045b3a6'}]},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z',
#   'org': {'id': 8529324,
#    'login': 'virtual-labs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/virtual-labs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8529324?'}},
#  {'id': '52644016263',
#   'type': 'PushEvent',
#   'actor': {'id': 50717432,
#    'login': 'AsmaaMahmoudSaeed',
#    'display_login': 'AsmaaMahmoudSaeed',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AsmaaMahmoudSaeed',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50717432?'},
#   'repo': {'id': 1027908928,
#    'name': 'AsmaaMahmoudSaeed/ATS',
#    'url': 'https://api.github.com/repos/AsmaaMahmoudSaeed/ATS'},
#   'payload': {'repository_id': 1027908928,
#    'push_id': 25777479058,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '8a9bf0bde91616c5d2af7d62027daef472f925b5',
#    'before': '54a83b3300f7361c8427d4677100d13ec08e2be9',
#    'commits': [{'sha': '8a9bf0bde91616c5d2af7d62027daef472f925b5',
#      'author': {'email': '50717432+AsmaaMahmoudSaeed@users.noreply.github.com',
#       'name': 'Asmaa Mahmoud'},
#      'message': 'Update app.py',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AsmaaMahmoudSaeed/ATS/commits/8a9bf0bde91616c5d2af7d62027daef472f925b5'}]},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z'},
#  {'id': '52644016295',
#   'type': 'PushEvent',
#   'actor': {'id': 23583091,
#    'login': 'khoshraftar',
#    'display_login': 'khoshraftar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/khoshraftar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23583091?'},
#   'repo': {'id': 999661916,
#    'name': 'khoshraftar/data-line',
#    'url': 'https://api.github.com/repos/khoshraftar/data-line'},
#   'payload': {'repository_id': 999661916,
#    'push_id': 25777479036,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b4b1a041598b7eb8b599525a4384d0f5c65d7d2a',
#    'before': '698ab4d3bf8ec1009b916430a3c6d6f3b15c7a87',
#    'commits': [{'sha': 'b4b1a041598b7eb8b599525a4384d0f5c65d7d2a',
#      'author': {'email': 'khoshraftar@divar.ir', 'name': 'khoshraftar'},
#      'message': 'Improve ui',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/khoshraftar/data-line/commits/b4b1a041598b7eb8b599525a4384d0f5c65d7d2a'}]},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z'},
#  {'id': '52644016287',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 372926961,
#    'name': 'RIAJ-GIT/RIAJ-GIT',
#    'url': 'https://api.github.com/repos/RIAJ-GIT/RIAJ-GIT'},
#   'payload': {'repository_id': 372926961,
#    'push_id': 25777479090,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '787063c97ad059e09c1629c994a04684cf92a253',
#    'before': 'dc3806686b288ffa99bf3e9be66c00af19b0a6a3',
#    'commits': [{'sha': '787063c97ad059e09c1629c994a04684cf92a253',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/RIAJ-GIT/RIAJ-GIT/commits/787063c97ad059e09c1629c994a04684cf92a253'}]},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z'},
#  {'id': '52644016299',
#   'type': 'CreateEvent',
#   'actor': {'id': 124264056,
#    'login': 'OmarElassal2004',
#    'display_login': 'OmarElassal2004',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/OmarElassal2004',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/124264056?'},
#   'repo': {'id': 1027925640,
#    'name': 'OmarElassal2004/start-framework',
#    'url': 'https://api.github.com/repos/OmarElassal2004/start-framework'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z'},
#  {'id': '52644016239',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 653007478,
#    'name': 'canpolatomer/canpolatomer',
#    'url': 'https://api.github.com/repos/canpolatomer/canpolatomer'},
#   'payload': {'repository_id': 653007478,
#    'push_id': 25777478998,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '787063c97ad059e09c1629c994a04684cf92a253',
#    'before': '2b916acdae2af62dbe84dc075f1d12f8dffe3062',
#    'commits': [{'sha': '787063c97ad059e09c1629c994a04684cf92a253',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/canpolatomer/canpolatomer/commits/787063c97ad059e09c1629c994a04684cf92a253'}]},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z'},
#  {'id': '52644016282',
#   'type': 'PushEvent',
#   'actor': {'id': 101381357,
#    'login': 'Rupesh3000',
#    'display_login': 'Rupesh3000',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Rupesh3000',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101381357?'},
#   'repo': {'id': 1027918940,
#    'name': 'acciojob/job-app-form-Rupesh3000',
#    'url': 'https://api.github.com/repos/acciojob/job-app-form-Rupesh3000'},
#   'payload': {'repository_id': 1027918940,
#    'push_id': 25777479064,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '03f0d30177fc72046eba2e04c8b62709b45e2d06',
#    'before': '2969e1634978c4dcf582a1d846ff45e4b9c7436d',
#    'commits': [{'sha': '03f0d30177fc72046eba2e04c8b62709b45e2d06',
#      'author': {'email': '101381357+Rupesh3000@users.noreply.github.com',
#       'name': 'Rupesh3000'},
#      'message': 'created a submission',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/acciojob/job-app-form-Rupesh3000/commits/03f0d30177fc72046eba2e04c8b62709b45e2d06'}]},
#   'public': True,
#   'created_at': '2025-07-28T18:36:47Z',
#   'org': {'id': 70142869,
#    'login': 'acciojob',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/acciojob',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/70142869?'}}]

# %%
r = requests.get ('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '["2022-11-28"]'

# %%
r = requests.get ('https://api.github.com/users/GaiasRaphael')
r.status_code
# Out:
# 200

# %%
r.json ()
# Out:
# {'login': 'GaiasRaphael',
#  'id': 168765618,
#  'node_id': 'U_kgDOCg8osg',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/168765618?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/GaiasRaphael',
#  'html_url': 'https://github.com/GaiasRaphael',
#  'followers_url': 'https://api.github.com/users/GaiasRaphael/followers',
#  'following_url': 'https://api.github.com/users/GaiasRaphael/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/GaiasRaphael/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/GaiasRaphael/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/GaiasRaphael/subscriptions',
#  'organizations_url': 'https://api.github.com/users/GaiasRaphael/orgs',
#  'repos_url': 'https://api.github.com/users/GaiasRaphael/repos',
#  'events_url': 'https://api.github.com/users/GaiasRaphael/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/GaiasRaphael/received_events',
#  'type': 'User',
#  'user_view_type': 'public',
#  'site_admin': False,
#  'name': None,
#  'company': None,
#  'blog': '',
#  'location': None,
#  'email': None,
#  'hireable': None,
#  'bio': None,
#  'twitter_username': None,
#  'public_repos': 4,
#  'public_gists': 0,
#  'followers': 0,
#  'following': 0,
#  'created_at': '2024-05-02T16:59:00Z',
#  'updated_at': '2025-07-22T11:20:08Z'}

# %%
r.url
# Out:
# 'https://api.github.com/users/GaiasRaphael'

# %%
import json

dados_user = r.json ()

print (dados_user)
# Out:
# {'login': 'GaiasRaphael', 'id': 168765618, 'node_id': 'U_kgDOCg8osg', 'avatar_url': 'https://avatars.githubusercontent.com/u/168765618?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/GaiasRaphael', 'html_url': 'https://github.com/GaiasRaphael', 'followers_url': 'https://api.github.com/users/GaiasRaphael/followers', 'following_url': 'https://api.github.com/users/GaiasRaphael/following{/other_user}', 'gists_url': 'https://api.github.com/users/GaiasRaphael/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/GaiasRaphael/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/GaiasRaphael/subscriptions', 'organizations_url': 'https://api.github.com/users/GaiasRaphael/orgs', 'repos_url': 'https://api.github.com/users/GaiasRaphael/repos', 'events_url': 'https://api.github.com/users/GaiasRaphael/events{/privacy}', 'received_events_url': 'https://api.github.com/users/GaiasRaphael/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False, 'name': None, 'company': None, 'blog': '', 'location': None, 'email': None, 'hireable': None, 'bio': None, 'twitter_username': None, 'public_repos': 4, 'public_gists': 0, 'followers': 0, 'following': 0, 'created_at': '2024-05-02T16:59:00Z', 'updated_at': '2025-07-22T11:20:08Z'}

# %%
print (dados_user['login'])
print (dados_user['name'])
print (dados_user['public_repos'])
print (dados_user['created_at'])
# Out:
# GaiasRaphael
# None
# 4
# 2024-05-02T16:59:00Z

# %%
headers = {'X-Github-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn'
url = f'{api_base_url}/users/{owner}/repos'

# %%
response = requests.get (url, headers=headers)
response.status_code
# Out:
# 200

# %%
response.json ()
# Out:
# [{'id': 171339259,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#   'name': '.github',
#   'full_name': 'amzn/.github',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/.github',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/.github',
#   'forks_url': 'https://api.github.com/repos/amzn/.github/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/.github/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/.github/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/.github/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/.github/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/.github/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/.github/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/.github/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/.github/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/.github/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/.github/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/.github/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/.github/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/.github/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/.github/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/.github/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/.github/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/.github/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/.github/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/.github/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/.github/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/.github/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/.github/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/.github/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/.github/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/.github/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/.github/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/.github/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/.github/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/.github/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/.github/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/.github/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/.github/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/.github/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/.github/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/.github/deployments',
#   'created_at': '2019-02-18T18:59:22Z',
#   'updated_at': '2025-07-16T22:32:21Z',
#   'pushed_at': '2024-10-18T22:23:05Z',
#   'git_url': 'git://github.com/amzn/.github.git',
#   'ssh_url': 'git@github.com:amzn/.github.git',
#   'clone_url': 'https://github.com/amzn/.github.git',
#   'svn_url': 'https://github.com/amzn/.github',
#   'homepage': None,
#   'size': 24,
#   'stargazers_count': 18,
#   'watchers_count': 18,
#   'language': None,
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 401,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 3,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 401,
#   'open_issues': 3,
#   'watchers': 18,
#   'default_branch': 'master'},
#  {'id': 492978607,
#   'node_id': 'R_kgDOHWJBrw',
#   'name': 'ads-advanced-tools-docs',
#   'full_name': 'amzn/ads-advanced-tools-docs',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#   'description': 'Code samples and supplements for the Amazon Ads advanced tools center',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/deployments',
#   'created_at': '2022-05-16T19:49:03Z',
#   'updated_at': '2025-07-23T13:07:57Z',
#   'pushed_at': '2025-03-25T21:20:38Z',
#   'git_url': 'git://github.com/amzn/ads-advanced-tools-docs.git',
#   'ssh_url': 'git@github.com:amzn/ads-advanced-tools-docs.git',
#   'clone_url': 'https://github.com/amzn/ads-advanced-tools-docs.git',
#   'svn_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#   'homepage': 'https://advertising.amazon.com/API/docs/en-us/index',
#   'size': 719,
#   'stargazers_count': 123,
#   'watchers_count': 123,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': True,
#   'forks_count': 41,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 30,
#   'license': {'key': 'mit-0',
#    'name': 'MIT No Attribution',
#    'spdx_id': 'MIT-0',
#    'url': 'https://api.github.com/licenses/mit-0',
#    'node_id': 'MDc6TGljZW5zZTQx'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['amazon', 'amazon-ads-api', 'amazon-marketing-stream'],
#   'visibility': 'public',
#   'forks': 41,
#   'open_issues': 30,
#   'watchers': 123,
#   'default_branch': 'main'},
#  {'id': 958141729,
#   'node_id': 'R_kgDOORwVIQ',
#   'name': 'ads-pao-amznjs-gtm-server-side-template',
#   'full_name': 'amzn/ads-pao-amznjs-gtm-server-side-template',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-server-side-template',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/deployments',
#   'created_at': '2025-03-31T17:58:12Z',
#   'updated_at': '2025-07-25T21:50:43Z',
#   'pushed_at': '2025-07-25T21:50:37Z',
#   'git_url': 'git://github.com/amzn/ads-pao-amznjs-gtm-server-side-template.git',
#   'ssh_url': 'git@github.com:amzn/ads-pao-amznjs-gtm-server-side-template.git',
#   'clone_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-server-side-template.git',
#   'svn_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-server-side-template',
#   'homepage': None,
#   'size': 91,
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'Smarty',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 1,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 1,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1,
#   'open_issues': 1,
#   'watchers': 1,
#   'default_branch': 'main'},
#  {'id': 674005216,
#   'node_id': 'R_kgDOKCyA4A',
#   'name': 'ads-pao-amznjs-gtm-template',
#   'full_name': 'amzn/ads-pao-amznjs-gtm-template',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/deployments',
#   'created_at': '2023-08-02T23:41:56Z',
#   'updated_at': '2025-07-25T06:31:19Z',
#   'pushed_at': '2024-06-03T16:53:23Z',
#   'git_url': 'git://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#   'ssh_url': 'git@github.com:amzn/ads-pao-amznjs-gtm-template.git',
#   'clone_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#   'svn_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#   'homepage': None,
#   'size': 165,
#   'stargazers_count': 3,
#   'watchers_count': 3,
#   'language': 'Smarty',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 3,
#   'default_branch': 'main'},
#  {'id': 41117941,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0MTExNzk0MQ==',
#   'name': 'alexa-coho',
#   'full_name': 'amzn/alexa-coho',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/alexa-coho',
#   'description': 'Sample code for building skill adapters for Alexa Connected Home using the Lighting API',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/alexa-coho',
#   'forks_url': 'https://api.github.com/repos/amzn/alexa-coho/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/alexa-coho/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/alexa-coho/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/alexa-coho/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/alexa-coho/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/alexa-coho/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/alexa-coho/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/alexa-coho/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/alexa-coho/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/alexa-coho/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/alexa-coho/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/alexa-coho/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/alexa-coho/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/alexa-coho/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/alexa-coho/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/alexa-coho/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/alexa-coho/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/alexa-coho/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/alexa-coho/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/alexa-coho/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/alexa-coho/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/alexa-coho/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/alexa-coho/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/alexa-coho/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/alexa-coho/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/alexa-coho/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/alexa-coho/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/alexa-coho/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/alexa-coho/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/alexa-coho/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/alexa-coho/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/alexa-coho/deployments',
#   'created_at': '2015-08-20T20:42:31Z',
#   'updated_at': '2024-07-11T01:03:40Z',
#   'pushed_at': '2023-04-01T08:35:29Z',
#   'git_url': 'git://github.com/amzn/alexa-coho.git',
#   'ssh_url': 'git@github.com:amzn/alexa-coho.git',
#   'clone_url': 'https://github.com/amzn/alexa-coho.git',
#   'svn_url': 'https://github.com/amzn/alexa-coho',
#   'homepage': None,
#   'size': 209,
#   'stargazers_count': 63,
#   'watchers_count': 63,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 25,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 4,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 25,
#   'open_issues': 4,
#   'watchers': 63,
#   'default_branch': 'master'},
#  {'id': 39471546,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzOTQ3MTU0Ng==',
#   'name': 'alexa-skills-kit-js',
#   'full_name': 'amzn/alexa-skills-kit-js',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/alexa-skills-kit-js',
#   'description': ' SDK and example code for building voice-enabled skills for the Amazon Echo. ',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js',
#   'forks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/deployments',
#   'created_at': '2015-07-21T21:46:48Z',
#   'updated_at': '2025-06-10T17:04:15Z',
#   'pushed_at': '2020-10-01T06:10:20Z',
#   'git_url': 'git://github.com/amzn/alexa-skills-kit-js.git',
#   'ssh_url': 'git@github.com:amzn/alexa-skills-kit-js.git',
#   'clone_url': 'https://github.com/amzn/alexa-skills-kit-js.git',
#   'svn_url': 'https://github.com/amzn/alexa-skills-kit-js',
#   'homepage': 'http://developer.amazon.com/ask',
#   'size': 8827,
#   'stargazers_count': 1137,
#   'watchers_count': 1137,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 1032,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 11,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1032,
#   'open_issues': 11,
#   'watchers': 1137,
#   'default_branch': 'master'},
#  {'id': 495519526,
#   'node_id': 'R_kgDOHYkHJg',
#   'name': 'amazon-ads-advertiser-audience-normalization-sdk-py',
#   'full_name': 'amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/deployments',
#   'created_at': '2022-05-23T17:59:56Z',
#   'updated_at': '2025-06-06T14:28:27Z',
#   'pushed_at': '2022-05-23T21:20:34Z',
#   'git_url': 'git://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'ssh_url': 'git@github.com:amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'clone_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'svn_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'homepage': None,
#   'size': 16,
#   'stargazers_count': 11,
#   'watchers_count': 11,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 3,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 3,
#   'open_issues': 0,
#   'watchers': 11,
#   'default_branch': 'main'},
#  {'id': 61315875,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk2MTMxNTg3NQ==',
#   'name': 'amazon-advertising-api-php-sdk',
#   'full_name': 'amzn/amazon-advertising-api-php-sdk',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#   'description': '⛔️ DEPRECATED - Amazon Advertising API PHP Client Library',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/deployments',
#   'created_at': '2016-06-16T18:16:46Z',
#   'updated_at': '2024-09-14T07:43:36Z',
#   'pushed_at': '2020-09-20T17:25:48Z',
#   'git_url': 'git://github.com/amzn/amazon-advertising-api-php-sdk.git',
#   'ssh_url': 'git@github.com:amzn/amazon-advertising-api-php-sdk.git',
#   'clone_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk.git',
#   'svn_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#   'homepage': '',
#   'size': 49,
#   'stargazers_count': 93,
#   'watchers_count': 93,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 66,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 14,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
# ...
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/deployments',
#   'created_at': '2024-07-31T06:15:43Z',
#   'updated_at': '2025-05-29T10:28:14Z',
#   'pushed_at': '2025-05-29T10:28:42Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-api-sdk-ruby.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-api-sdk-ruby.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-api-sdk-ruby.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-api-sdk-ruby',
#   'homepage': None,
#   'size': 52,
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': 'Ruby',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 1,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1,
#   'open_issues': 0,
#   'watchers': 2,
#   'default_branch': 'main'},
#  {'id': 33279165,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMzI3OTE2NQ==',
#   'name': 'amazon-pay-code-samples',
#   'full_name': 'amzn/amazon-pay-code-samples',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-pay-code-samples',
#   'description': 'Amazon Pay SDK Sample Code',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/deployments',
#   'created_at': '2015-04-01T23:52:35Z',
#   'updated_at': '2025-05-26T08:41:56Z',
#   'pushed_at': '2023-04-10T09:51:00Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-code-samples.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-code-samples.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-code-samples.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-code-samples',
#   'homepage': '',
#   'size': 4573,
#   'stargazers_count': 43,
#   'watchers_count': 43,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': True,
#   'has_discussions': False,
#   'forks_count': 32,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 10,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 32,
#   'open_issues': 10,
#   'watchers': 43,
#   'default_branch': 'master'},
#  {'id': 27617078,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNzYxNzA3OA==',
#   'name': 'amazon-pay-sdk-csharp',
#   'full_name': 'amzn/amazon-pay-sdk-csharp',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-pay-sdk-csharp',
#   'description': 'Amazon Pay C# SDK',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/deployments',
#   'created_at': '2014-12-06T01:01:38Z',
#   'updated_at': '2025-06-22T21:57:29Z',
#   'pushed_at': '2024-05-30T18:46:45Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-csharp.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-csharp.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-csharp.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-csharp',
#   'homepage': 'https://payments.amazon.com/developer',
#   'size': 28264,
#   'stargazers_count': 48,
#   'watchers_count': 48,
#   'language': 'C#',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 40,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 11,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 40,
#   'open_issues': 11,
#   'watchers': 48,
#   'default_branch': 'master'}]

# %%
len (response.json ())
# Out:
# 30

# %%
response.url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
access_token = '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'
headers = {'Authorization': 'Bearer' + access_token, 
           'X-Github-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn'
url = f'{api_base_url}/users/{owner}/repos'

url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
repos_list = []

for page_num in range (1, 6):
    try:
        url_page = f'{url}?page={page_num}'
        response = requests.get(url_page, headers=headers)
        repos_list.append (response.json ())
    except:
        repos_list.append (None)

# %%
repos_list[0]
# Out:
# [{'id': 171339259,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#   'name': '.github',
#   'full_name': 'amzn/.github',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/.github',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/.github',
#   'forks_url': 'https://api.github.com/repos/amzn/.github/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/.github/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/.github/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/.github/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/.github/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/.github/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/.github/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/.github/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/.github/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/.github/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/.github/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/.github/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/.github/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/.github/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/.github/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/.github/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/.github/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/.github/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/.github/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/.github/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/.github/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/.github/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/.github/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/.github/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/.github/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/.github/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/.github/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/.github/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/.github/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/.github/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/.github/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/.github/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/.github/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/.github/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/.github/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/.github/deployments',
#   'created_at': '2019-02-18T18:59:22Z',
#   'updated_at': '2025-07-16T22:32:21Z',
#   'pushed_at': '2024-10-18T22:23:05Z',
#   'git_url': 'git://github.com/amzn/.github.git',
#   'ssh_url': 'git@github.com:amzn/.github.git',
#   'clone_url': 'https://github.com/amzn/.github.git',
#   'svn_url': 'https://github.com/amzn/.github',
#   'homepage': None,
#   'size': 24,
#   'stargazers_count': 18,
#   'watchers_count': 18,
#   'language': None,
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 401,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 3,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 401,
#   'open_issues': 3,
#   'watchers': 18,
#   'default_branch': 'master'},
#  {'id': 492978607,
#   'node_id': 'R_kgDOHWJBrw',
#   'name': 'ads-advanced-tools-docs',
#   'full_name': 'amzn/ads-advanced-tools-docs',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#   'description': 'Code samples and supplements for the Amazon Ads advanced tools center',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/deployments',
#   'created_at': '2022-05-16T19:49:03Z',
#   'updated_at': '2025-07-23T13:07:57Z',
#   'pushed_at': '2025-03-25T21:20:38Z',
#   'git_url': 'git://github.com/amzn/ads-advanced-tools-docs.git',
#   'ssh_url': 'git@github.com:amzn/ads-advanced-tools-docs.git',
#   'clone_url': 'https://github.com/amzn/ads-advanced-tools-docs.git',
#   'svn_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#   'homepage': 'https://advertising.amazon.com/API/docs/en-us/index',
#   'size': 719,
#   'stargazers_count': 123,
#   'watchers_count': 123,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': True,
#   'forks_count': 41,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 30,
#   'license': {'key': 'mit-0',
#    'name': 'MIT No Attribution',
#    'spdx_id': 'MIT-0',
#    'url': 'https://api.github.com/licenses/mit-0',
#    'node_id': 'MDc6TGljZW5zZTQx'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['amazon', 'amazon-ads-api', 'amazon-marketing-stream'],
#   'visibility': 'public',
#   'forks': 41,
#   'open_issues': 30,
#   'watchers': 123,
#   'default_branch': 'main'},
#  {'id': 958141729,
#   'node_id': 'R_kgDOORwVIQ',
#   'name': 'ads-pao-amznjs-gtm-server-side-template',
#   'full_name': 'amzn/ads-pao-amznjs-gtm-server-side-template',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-server-side-template',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/deployments',
#   'created_at': '2025-03-31T17:58:12Z',
#   'updated_at': '2025-07-25T21:50:43Z',
#   'pushed_at': '2025-07-25T21:50:37Z',
#   'git_url': 'git://github.com/amzn/ads-pao-amznjs-gtm-server-side-template.git',
#   'ssh_url': 'git@github.com:amzn/ads-pao-amznjs-gtm-server-side-template.git',
#   'clone_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-server-side-template.git',
#   'svn_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-server-side-template',
#   'homepage': None,
#   'size': 91,
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'Smarty',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 1,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 1,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1,
#   'open_issues': 1,
#   'watchers': 1,
#   'default_branch': 'main'},
#  {'id': 674005216,
#   'node_id': 'R_kgDOKCyA4A',
#   'name': 'ads-pao-amznjs-gtm-template',
#   'full_name': 'amzn/ads-pao-amznjs-gtm-template',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/deployments',
#   'created_at': '2023-08-02T23:41:56Z',
#   'updated_at': '2025-07-25T06:31:19Z',
#   'pushed_at': '2024-06-03T16:53:23Z',
#   'git_url': 'git://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#   'ssh_url': 'git@github.com:amzn/ads-pao-amznjs-gtm-template.git',
#   'clone_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#   'svn_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#   'homepage': None,
#   'size': 165,
#   'stargazers_count': 3,
#   'watchers_count': 3,
#   'language': 'Smarty',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 3,
#   'default_branch': 'main'},
#  {'id': 41117941,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0MTExNzk0MQ==',
#   'name': 'alexa-coho',
#   'full_name': 'amzn/alexa-coho',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/alexa-coho',
#   'description': 'Sample code for building skill adapters for Alexa Connected Home using the Lighting API',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/alexa-coho',
#   'forks_url': 'https://api.github.com/repos/amzn/alexa-coho/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/alexa-coho/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/alexa-coho/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/alexa-coho/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/alexa-coho/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/alexa-coho/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/alexa-coho/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/alexa-coho/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/alexa-coho/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/alexa-coho/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/alexa-coho/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/alexa-coho/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/alexa-coho/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/alexa-coho/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/alexa-coho/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/alexa-coho/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/alexa-coho/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/alexa-coho/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/alexa-coho/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/alexa-coho/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/alexa-coho/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/alexa-coho/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/alexa-coho/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/alexa-coho/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/alexa-coho/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/alexa-coho/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/alexa-coho/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/alexa-coho/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/alexa-coho/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/alexa-coho/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/alexa-coho/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/alexa-coho/deployments',
#   'created_at': '2015-08-20T20:42:31Z',
#   'updated_at': '2024-07-11T01:03:40Z',
#   'pushed_at': '2023-04-01T08:35:29Z',
#   'git_url': 'git://github.com/amzn/alexa-coho.git',
#   'ssh_url': 'git@github.com:amzn/alexa-coho.git',
#   'clone_url': 'https://github.com/amzn/alexa-coho.git',
#   'svn_url': 'https://github.com/amzn/alexa-coho',
#   'homepage': None,
#   'size': 209,
#   'stargazers_count': 63,
#   'watchers_count': 63,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 25,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 4,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 25,
#   'open_issues': 4,
#   'watchers': 63,
#   'default_branch': 'master'},
#  {'id': 39471546,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzOTQ3MTU0Ng==',
#   'name': 'alexa-skills-kit-js',
#   'full_name': 'amzn/alexa-skills-kit-js',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/alexa-skills-kit-js',
#   'description': ' SDK and example code for building voice-enabled skills for the Amazon Echo. ',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js',
#   'forks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/deployments',
#   'created_at': '2015-07-21T21:46:48Z',
#   'updated_at': '2025-06-10T17:04:15Z',
#   'pushed_at': '2020-10-01T06:10:20Z',
#   'git_url': 'git://github.com/amzn/alexa-skills-kit-js.git',
#   'ssh_url': 'git@github.com:amzn/alexa-skills-kit-js.git',
#   'clone_url': 'https://github.com/amzn/alexa-skills-kit-js.git',
#   'svn_url': 'https://github.com/amzn/alexa-skills-kit-js',
#   'homepage': 'http://developer.amazon.com/ask',
#   'size': 8827,
#   'stargazers_count': 1137,
#   'watchers_count': 1137,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 1032,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 11,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1032,
#   'open_issues': 11,
#   'watchers': 1137,
#   'default_branch': 'master'},
#  {'id': 495519526,
#   'node_id': 'R_kgDOHYkHJg',
#   'name': 'amazon-ads-advertiser-audience-normalization-sdk-py',
#   'full_name': 'amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/deployments',
#   'created_at': '2022-05-23T17:59:56Z',
#   'updated_at': '2025-06-06T14:28:27Z',
#   'pushed_at': '2022-05-23T21:20:34Z',
#   'git_url': 'git://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'ssh_url': 'git@github.com:amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'clone_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'svn_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'homepage': None,
#   'size': 16,
#   'stargazers_count': 11,
#   'watchers_count': 11,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 3,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 3,
#   'open_issues': 0,
#   'watchers': 11,
#   'default_branch': 'main'},
#  {'id': 61315875,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk2MTMxNTg3NQ==',
#   'name': 'amazon-advertising-api-php-sdk',
#   'full_name': 'amzn/amazon-advertising-api-php-sdk',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#   'description': '⛔️ DEPRECATED - Amazon Advertising API PHP Client Library',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/deployments',
#   'created_at': '2016-06-16T18:16:46Z',
#   'updated_at': '2024-09-14T07:43:36Z',
#   'pushed_at': '2020-09-20T17:25:48Z',
#   'git_url': 'git://github.com/amzn/amazon-advertising-api-php-sdk.git',
#   'ssh_url': 'git@github.com:amzn/amazon-advertising-api-php-sdk.git',
#   'clone_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk.git',
#   'svn_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#   'homepage': '',
#   'size': 49,
#   'stargazers_count': 93,
#   'watchers_count': 93,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 66,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 14,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
# ...
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/deployments',
#   'created_at': '2024-07-31T06:15:43Z',
#   'updated_at': '2025-05-29T10:28:14Z',
#   'pushed_at': '2025-05-29T10:28:42Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-api-sdk-ruby.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-api-sdk-ruby.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-api-sdk-ruby.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-api-sdk-ruby',
#   'homepage': None,
#   'size': 52,
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': 'Ruby',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 1,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1,
#   'open_issues': 0,
#   'watchers': 2,
#   'default_branch': 'main'},
#  {'id': 33279165,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMzI3OTE2NQ==',
#   'name': 'amazon-pay-code-samples',
#   'full_name': 'amzn/amazon-pay-code-samples',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-pay-code-samples',
#   'description': 'Amazon Pay SDK Sample Code',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/deployments',
#   'created_at': '2015-04-01T23:52:35Z',
#   'updated_at': '2025-05-26T08:41:56Z',
#   'pushed_at': '2023-04-10T09:51:00Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-code-samples.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-code-samples.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-code-samples.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-code-samples',
#   'homepage': '',
#   'size': 4573,
#   'stargazers_count': 43,
#   'watchers_count': 43,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': True,
#   'has_discussions': False,
#   'forks_count': 32,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 10,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 32,
#   'open_issues': 10,
#   'watchers': 43,
#   'default_branch': 'master'},
#  {'id': 27617078,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNzYxNzA3OA==',
#   'name': 'amazon-pay-sdk-csharp',
#   'full_name': 'amzn/amazon-pay-sdk-csharp',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-pay-sdk-csharp',
#   'description': 'Amazon Pay C# SDK',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/deployments',
#   'created_at': '2014-12-06T01:01:38Z',
#   'updated_at': '2025-06-22T21:57:29Z',
#   'pushed_at': '2024-05-30T18:46:45Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-csharp.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-csharp.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-csharp.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-csharp',
#   'homepage': 'https://payments.amazon.com/developer',
#   'size': 28264,
#   'stargazers_count': 48,
#   'watchers_count': 48,
#   'language': 'C#',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 40,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 11,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 40,
#   'open_issues': 11,
#   'watchers': 48,
#   'default_branch': 'master'}]

# %%
len (repos_list)
# Out:
# 5

# %%
repos_name = []

for page in repos_list:
    for repo in page:
        repos_name.append (repo['name'])

repos_name
# Out:
# ['.github',
#  'ads-advanced-tools-docs',
#  'ads-pao-amznjs-gtm-server-side-template',
#  'ads-pao-amznjs-gtm-template',
#  'alexa-coho',
#  'alexa-skills-kit-js',
#  'amazon-ads-advertiser-audience-normalization-sdk-py',
#  'amazon-advertising-api-php-sdk',
#  'amazon-codeguru-profiler-for-spark',
#  'amazon-frustration-free-setup-certification-tool',
#  'amazon-hub-counter-api-docs',
#  'amazon-hub-counter-api-samples',
#  'amazon-hub-counter-sdk-java',
#  'amazon-hub-support',
#  'amazon-instant-access-sdk-java',
#  'amazon-instant-access-sdk-net',
#  'amazon-instant-access-sdk-php',
#  'amazon-instant-access-sdk-ruby',
#  'amazon-launcher-integration-cordova-plugin',
#  'amazon-marketing-stream-examples',
#  'amazon-mcf-plugin-for-magento-1',
#  'amazon-multi-token-completion',
#  'amazon-nearest-neighbor-through-ecc',
#  'amazon-pay-api-sdk-dotnet',
#  'amazon-pay-api-sdk-java',
#  'amazon-pay-api-sdk-nodejs',
#  'amazon-pay-api-sdk-php',
#  'amazon-pay-api-sdk-ruby',
#  'amazon-pay-code-samples',
#  'amazon-pay-sdk-csharp',
#  'amazon-pay-sdk-java',
#  'amazon-pay-sdk-php',
#  'amazon-pay-sdk-python',
#  'amazon-pay-sdk-ruby',
#  'amazon-payment-files-tools',
#  'amazon-payments-magento-2-plugin',
#  'amazon-ray',
#  'amazon-s3-gst-plugin',
#  'amazon-sidewalk-android-samples',
#  'amazon-sidewalk-ios-samples',
#  'amazon-succinct-doc-representation',
#  'amazon-template-library',
#  'amazon-weak-ner-needle',
#  'amigitenough',
#  'amzn-drivers',
#  'amzn-ec2-ena-utilities',
#  'app-platform',
#  'armbench',
#  'augment-the-pairs-wacv2024',
#  'autotrail',
#  'aws-apigateway-client-lib',
#  'aws-sigv4-signing-samples',
#  'awsssmchaosrunner',
#  'basis-point-sets',
#  'BayesPE',
#  'buy-with-prime-cdk-constructs',
#  'buy-with-prime-monitoring-sample-cdk',
#  'chalet-charging-location-for-electric-trucks',
#  'computer-vision-basics-in-microsoft-excel',
#  'confident-sinkhorn-allocation',
#  'convolutional-handwriting-gan',
#  'cosearcher',
#  'credence-to-causal-estimation',
#  'data-jack-knife',
#  'debiased-balanced-interleaving',
#  'differential-privacy-bayesian-optimization',
#  'distance-assistant',
#  'drs-sample-android-app',
#  'drs-sample-ios-app',
#  'emukit-playground',
#  'eslint-plugin-no-date-parsing',
#  'exoplayer-amazon-port',
#  'explainable-text-vqa',
#  'extremely-efficient-query-encoder',
#  'faithful-data2text-cycle-training',
#  'fashion-attribute-disentanglement',
#  'fire-app-builder',
#  'firetv-sample-touch-app',
#  'ftv-integration-sdk-sample-app',
#  'ftv-livetv-sample-tv-app',
#  'gameon-sample-game-unity',
#  'gameon-starter-kit-unity',
#  'git-commit-template',
#  'glad',
#  'golang-gitoperations',
#  'halo-third-party-sdk-for-java',
#  'halo-third-party-sdk-for-node-js',
#  'halo-third-party-sdk-for-python',
#  'hawktracer',
#  'image-misspell-coling2020',
#  'image-to-recipe-transformers',
#  'informative-diverse-hard-negative-sampling',
#  'ion-cascading-config',
#  'ion-object-mapper-dotnet',
#  'jekyll-doc-project',
#  'kotlin-inject-anvil',
#  'kqr',
#  'lib-3d-scene-viewer',
#  'login-with-amazon-oscommerce',
#  'login-with-amazon-wordpress',
#  'media3-external-port',
#  'merlin-on-demand-callgraph',
#  'metalearn-leap',
#  'milan',
#  'MonitoringCustomMetrics',
#  'mrc-net-6d-pose',
#  'multiconer-baseline',
#  'multilingual-keyphrase-generation',
#  'multimodal-affinities',
#  'MXFusion',
#  'nimbus-jose-jwt_aws-kms-extension',
#  'node-jose_aws-kms-extension',
#  'openapi-swift-code-generate',
#  'orthogonal-additive-gaussian-processes',
#  'oss-attribution-builder',
#  'oss-contribution-tracker',
#  'oss-dashboard',
#  'pecos',
#  'pretraining-or-self-training',
#  'python-jose_aws-kms-extension',
#  'rdma-core',
#  'refuel-open-domain-qa',
#  'rete-thewebconf-2022',
#  'rheoceros',
#  'robotiq-gripper-interface',
#  'selling-partner-api-docs',
#  'selling-partner-api-models',
#  'selling-partner-api-php-release',
#  'selling-partner-api-samples',
#  'selling-partner-api-sdk',
#  'seqzero',
#  'service-model-swift-code-generate',
#  'sid-provision',
#  'sid-signing-tool',
#  'sketch-constructor',
#  'smoke-aws',
#  'smoke-aws-credentials',
#  'smoke-aws-generate',
#  'smoke-aws-support',
#  'smoke-dynamodb',
#  'smoke-framework',
#  'smoke-framework-application-generate',
#  'smoke-framework-examples',
#  'smoke-http',
#  'sparse-vqvae',
#  'ss-aga-kgc',
#  'sto-transformer',
#  'supply-chain-simulation-environment',
#  'tiny-attribution-generator',
#  'traffic-quality-smart-pixel-loader']

# %%
len (repos_name)
# Out:
# 150

# %%
repos_list[1][1]['language']
# Out:
# 'PHP'

# %%
repos_language = []

for page in repos_list:
    for repo in page:
        repos_language.append (repo['language'])

# %%
repos_language
# Out:
# [None,
#  'Jupyter Notebook',
#  'Smarty',
#  'Smarty',
#  'JavaScript',
#  None,
#  'Python',
#  'PHP',
#  'Java',
#  'Python',
#  'CSS',
#  'Java',
#  'Java',
#  'PowerShell',
#  'Java',
#  'C#',
#  'PHP',
#  'Ruby',
#  'JavaScript',
#  'Python',
#  'PHP',
#  'Python',
#  'Jupyter Notebook',
#  'C#',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'Ruby',
#  'PHP',
#  'C#',
#  'Java',
#  'PHP',
#  'Python',
#  'Ruby',
#  'Kotlin',
#  'PHP',
#  'Python',
#  'C',
#  None,
#  'Swift',
#  'Python',
#  'C++',
#  'Python',
#  'Go',
#  'C',
#  'Python',
#  'Kotlin',
#  'Python',
#  'Python',
#  'Python',
#  None,
#  'Java',
#  'Kotlin',
#  'Python',
#  'Python',
#  'TypeScript',
#  'TypeScript',
#  'Python',
#  None,
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Java',
#  'Objective-C',
#  'JavaScript',
#  'TypeScript',
#  'Java',
#  None,
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'Java',
#  'Kotlin',
#  'Java',
#  'C#',
#  'C#',
#  'JavaScript',
#  'JavaScript',
#  'Go',
#  'Java',
#  'TypeScript',
#  'Python',
#  'C++',
#  None,
#  'Python',
#  'Python',
#  'Java',
#  'C#',
#  'HTML',
#  'Kotlin',
#  None,
#  'TypeScript',
#  'PHP',
#  'PHP',
#  None,
#  'JavaScript',
#  'Python',
#  'Scala',
#  'Python',
#  'Python',
#  'Python',
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'TypeScript',
#  'Swift',
#  'Python',
#  'TypeScript',
#  'TypeScript',
#  'Ruby',
#  'Python',
#  'Python',
#  'Python',
#  'C',
#  'Python',
#  'Python',
#  'Python',
#  'C++',
#  None,
#  'Mustache',
#  'PHP',
#  'Java',
#  'PHP',
#  'Python',
#  'Swift',
#  'Python',
#  'Python',
#  'JavaScript',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Python',
#  'Python',
#  'Python',
#  'Python',
#  'TypeScript',
#  'TypeScript']

# %% [markdown]
# Criando DataFrame

# %%
import pandas as pd

# %%
dados_amz = pd.DataFrame ()
dados_amz['Name'] = repos_name
dados_amz['Language'] = repos_language

# %%
dados_amz
# Out:
#                                         Name          Language
# 0                                    .github              None
# 1                    ads-advanced-tools-docs  Jupyter Notebook
# 2    ads-pao-amznjs-gtm-server-side-template            Smarty
# 3                ads-pao-amznjs-gtm-template            Smarty
# 4                                 alexa-coho        JavaScript
# ..                                       ...               ...
# 145                               ss-aga-kgc            Python
# 146                          sto-transformer            Python
# 147      supply-chain-simulation-environment            Python
# 148               tiny-attribution-generator        TypeScript
# 149       traffic-quality-smart-pixel-loader        TypeScript
#
# [150 rows x 2 columns]

# %% [markdown]
# Salvando DataFrame

# %%
dados_amz.to_csv ('amazon.csv')

# %%
repo_python = pd.DataFrame ()

# %%
list_python = []
for num in range (1, len (repos_language)):
    if repos_language[num] == 'Python':
        list_python.append (repos_name[num])

repo_python['Name'] = list_python

# %%
repo_python
# Out:
#                                                  Name
# 0   amazon-ads-advertiser-audience-normalization-s...
# 1    amazon-frustration-free-setup-certification-tool
# 2                    amazon-marketing-stream-examples
# 3                       amazon-multi-token-completion
# 4                               amazon-pay-sdk-python
# 5                                          amazon-ray
# 6                  amazon-succinct-doc-representation
# 7                              amazon-weak-ner-needle
# 8                              amzn-ec2-ena-utilities
# 9                                            armbench
# 10                         augment-the-pairs-wacv2024
# 11                                          autotrail
# 12                                   basis-point-sets
# 13                                            BayesPE
# 14       chalet-charging-location-for-electric-trucks
# 15                      convolutional-handwriting-gan
# 16                                         cosearcher
# 17                      credence-to-causal-estimation
# 18         differential-privacy-bayesian-optimization
# 19                                 distance-assistant
# 20                  extremely-efficient-query-encoder
# 21                  faithful-data2text-cycle-training
# 22                  fashion-attribute-disentanglement
# 23                    halo-third-party-sdk-for-python
# 24                       image-to-recipe-transformers
# 25         informative-diverse-hard-negative-sampling
# 26                                     metalearn-leap
# 27                            MonitoringCustomMetrics
# 28                                    mrc-net-6d-pose
# 29                                multiconer-baseline
# 30                  multilingual-keyphrase-generation
# 31                              multimodal-affinities
# 32                                           MXFusion
# 33             orthogonal-additive-gaussian-processes
# 34                                              pecos
# 35                       pretraining-or-self-training
# 36                      python-jose_aws-kms-extension
# 37                              refuel-open-domain-qa
# 38                               rete-thewebconf-2022
# 39                                          rheoceros
# 40                                            seqzero
# 41                                      sid-provision
# 42                                   sid-signing-tool
# 43                                       sparse-vqvae
# 44                                         ss-aga-kgc
# 45                                    sto-transformer
# 46                supply-chain-simulation-environment

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn'
url = f'{api_base_url}/users/{owner}/followers'

url
# Out:
# 'https://api.github.com/users/amzn/followers'
