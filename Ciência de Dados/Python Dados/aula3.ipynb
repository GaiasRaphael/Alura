# %%
import matplotlib.pyplot as plt

# %%
nomes = ["João", "Maria", "Carlos", "pedro"]
medias = [7.5, 8.2, 6.9, 9.7]

plt.bar(nomes, medias)
plt.xlabel("Nomes")
plt.ylabel("Média")
plt.title("Média Final")

plt.show()

# %%
for contador in range(0,3):
    nota_1 = float(input())
    nota_2 = float(input())

    print (f'Media: {(nota_1 + nota_2) / 2}\n')
# Out:
# Media: 5.25
#
# Media: 7.45
#
# Media: 9.55

# %%
bac_a = 4
bac_b = 10
i = 0

while bac_a <= bac_b:
    i += 1
    bac_a *= 1.03
    bac_b *= 1.015

print (f"Dias para A ultrapassar B: {i}")
# Out:
# Dias para A ultrapassar B: 63

# %%
def fact (n):
    if n == 0:
        return 1
    return n * fact (n - 1)
# Out:
# 120

# %%
loja = {'nomes': ['televisão', 'celular', 'notebook', 'geladeira', 'fogão'],
        'precos': [2000, 1500, 3500, 4000, 1500]}

# %%
for chave, elementos in loja.items():
  print(f'Chave: {chave}\nElementos:')
  for dado in elementos:
    print(dado)
# Out:
# Chave: nomes
# Elementos:
# televisão
# celular
# notebook
# geladeira
# fogão
# Chave: precos
# Elementos:
# 2000
# 1500
# 3500
# 4000
# 1500
