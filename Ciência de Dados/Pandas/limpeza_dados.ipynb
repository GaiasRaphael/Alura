# %% [markdown]
# ##IMPORTANDO BIBLIOTECAS

# %%
import pandas as pd
import numpy as np
import json
import seaborn as sns

# %%
df_churn = pd.read_json ('https://cdn3.gnarususercontent.com.br/2929-pandas/dataset-telecon.json', storage_options={'User-Agent': 'Mozilla/5.0'})

# %%
df_churn
# Out:
#       id_cliente Churn                                            cliente  \
# 0     0002-ORFBO   nao  {'genero': 'feminino', 'idoso': 0, 'parceiro':...
# 1     0003-MKNFE   nao  {'genero': 'masculino', 'idoso': 0, 'parceiro'...
# 2     0004-TLHLJ   sim  {'genero': 'masculino', 'idoso': 0, 'parceiro'...
# 3     0011-IGKFF   sim  {'genero': 'masculino', 'idoso': 1, 'parceiro'...
# 4     0013-EXCHZ   sim  {'genero': 'feminino', 'idoso': 1, 'parceiro':...
# ...          ...   ...                                                ...
# 7339  5172-RKOCB   nao  {'genero': 'masculino', 'idoso': 0, 'parceiro'...
# 7340  1934-MKPXS   nao  {'genero': 'masculino', 'idoso': 0, 'parceiro'...
# 7341  5959-BELXA   sim  {'genero': 'masculino', 'idoso': 1, 'parceiro'...
# 7342  3601-UTZXO        {'genero': 'masculino', 'idoso': 0, 'parceiro'...
# 7343  4452-QIIEB   nao  {'genero': 'masculino', 'idoso': 0, 'parceiro'...
#
#                                                telefone  \
# ...

# %%
pd.json_normalize(df_churn['conta'])
# Out:
#        contrato faturamente_eletronico                     metodo_pagamento  \
# 0          None                   None                                 None
# 1     mes a mes                    nao                  cheque pelo correio
# 2     mes a mes                    sim                    cheque eletronico
# 3     mes a mes                    sim                    cheque eletronico
# 4     mes a mes                    sim                  cheque pelo correio
# ...         ...                    ...                                  ...
# 7339  dois anos                    sim       cartao de credito (automatico)
# 7340     um ano                    nao       cartao de credito (automatico)
# 7341  mes a mes                    sim       cartao de credito (automatico)
# 7342     um ano                    nao  transferencia bancaria (automatica)
# 7343  mes a mes                    nao                  cheque pelo correio
#
#       cobranca.mensal cobranca.Total
# ...

# %%
df_churn
# Out:
#       id_cliente Churn                                            cliente  \
# 0     0002-ORFBO   nao  {'genero': 'feminino', 'idoso': 0, 'parceiro':...
# 1     0003-MKNFE   nao  {'genero': 'masculino', 'idoso': 0, 'parceiro'...
# 2     0004-TLHLJ   sim  {'genero': 'masculino', 'idoso': 0, 'parceiro'...
# 3     0011-IGKFF   sim  {'genero': 'masculino', 'idoso': 1, 'parceiro'...
# 4     0013-EXCHZ   sim  {'genero': 'feminino', 'idoso': 1, 'parceiro':...
# ...          ...   ...                                                ...
# 7339  5172-RKOCB   nao  {'genero': 'masculino', 'idoso': 0, 'parceiro'...
# 7340  1934-MKPXS   nao  {'genero': 'masculino', 'idoso': 0, 'parceiro'...
# 7341  5959-BELXA   sim  {'genero': 'masculino', 'idoso': 1, 'parceiro'...
# 7342  3601-UTZXO        {'genero': 'masculino', 'idoso': 0, 'parceiro'...
# 7343  4452-QIIEB   nao  {'genero': 'masculino', 'idoso': 0, 'parceiro'...
#
#                                                telefone  \
# ...

# %%
with open ('dataset-telecon.json') as file:
    json_bruto = json.load (file)

json_bruto
# Out:
# [{'id_cliente': '0002-ORFBO',
#   'Churn': 'nao',
#   'cliente': {'genero': 'feminino',
#    'idoso': 0,
#    'parceiro': 'sim',
#    'dependentes': 'sim',
#    'tempo_servico': 9},
#   'telefone': {'servico_telefone': 'sim', 'varias_linhas': 'nao'},
#   'internet': {'servico_internet': 'DSL',
#    'seguranca_online': 'nao',
#    'backup_online': 'sim',
#    'protecao_dispositivo': 'nao',
#    'suporte_tecnico': 'sim',
#    'tv_streaming': 'sim',
#    'filmes_streaming': 'nao'},
#   'conta': {'contrato': None,
#    'faturamente_eletronico': None,
#    'metodo_pagamento': None,
#    'cobranca': {'mensal': None, 'Total': None}}},
#  {'id_cliente': '0003-MKNFE',
#   'Churn': 'nao',
#   'cliente': {'genero': 'masculino',
#    'idoso': 0,
#    'parceiro': 'nao',
#    'dependentes': 'nao',
#    'tempo_servico': 9},
#   'telefone': {'servico_telefone': 'sim', 'varias_linhas': 'sim'},
#   'internet': {'servico_internet': 'DSL',
#    'seguranca_online': 'nao',
#    'backup_online': 'nao',
# ...

# %%
dados_normalizados = pd.json_normalize (json_bruto)
dados_normalizados
# Out:
#       id_cliente Churn cliente.genero  cliente.idoso cliente.parceiro  \
# 0     0002-ORFBO   nao       feminino              0              sim
# 1     0003-MKNFE   nao      masculino              0              nao
# 2     0004-TLHLJ   sim      masculino              0              nao
# 3     0011-IGKFF   sim      masculino              1              sim
# 4     0013-EXCHZ   sim       feminino              1              sim
# ...          ...   ...            ...            ...              ...
# 7339  5172-RKOCB   nao      masculino              0              sim
# 7340  1934-MKPXS   nao      masculino              0              sim
# 7341  5959-BELXA   sim      masculino              1              nao
# 7342  3601-UTZXO            masculino              0              sim
# 7343  4452-QIIEB   nao      masculino              0              nao
#
#      cliente.dependentes  cliente.tempo_servico telefone.servico_telefone  \
# ...

# %%
dados_normalizados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7344 entries, 0 to 7343
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id_cliente                     7344 non-null   object
#  1   Churn                          7344 non-null   object
#  2   cliente.genero                 7344 non-null   object
#  3   cliente.idoso                  7344 non-null   int64
#  4   cliente.parceiro               7344 non-null   object
#  5   cliente.dependentes            7344 non-null   object
#  6   cliente.tempo_servico          7336 non-null   float64
#  7   telefone.servico_telefone      7344 non-null   object
#  8   telefone.varias_linhas         7344 non-null   object
#  9   internet.servico_internet      7344 non-null   object
#  10  internet.seguranca_online      7344 non-null   object
#  11  internet.backup_online         7344 non-null   object
# ...

# %%
idx = dados_normalizados[dados_normalizados['conta.cobranca.Total'] == ' ' ].index

# %%
dados_normalizados.loc[idx, 'conta.cobranca.Total'] = dados_normalizados.loc[idx, 'conta.cobranca.mensal'] * 24

# %%
dados_normalizados.loc[idx, 'cliente.tempo_servico'] = 24

# %%
dados_normalizados.loc[idx]
# Out:
#       id_cliente Churn cliente.genero  cliente.idoso cliente.parceiro  \
# 975   1371-DWPAZ   nao       feminino              0              sim
# 1775  2520-SGTTA   nao       feminino              0              sim
# 1955  2775-SEFEE   nao      masculino              0              nao
# 2075  2923-ARZLG   nao      masculino              0              sim
# 2232  3115-CZMZD   nao      masculino              0              nao
# 2308  3213-VVOLG   nao      masculino              0              sim
# 2930  4075-WKNIU   nao       feminino              0              sim
# 3134  4367-NUYAO   nao      masculino              0              sim
# 3203  4472-LVYGI   nao       feminino              0              sim
# 4169  5709-LVOEQ   nao       feminino              0              sim
# 5599  7644-OMVMY   nao      masculino              0              sim
#
#      cliente.dependentes  cliente.tempo_servico telefone.servico_telefone  \
# ...

# %%
dados_normalizados['conta.cobranca.Total'] = dados_normalizados['conta.cobranca.Total'].astype (float)

# %%
dados_normalizados['conta.cobranca.Total'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7344 entries, 0 to 7343
# Series name: conta.cobranca.Total
# Non-Null Count  Dtype
# --------------  -----
# 7328 non-null   float64
# dtypes: float64(1)
# memory usage: 57.5 KB

# %%
dados_normalizados.query ("Churn == ''")
# Out:
#       id_cliente Churn cliente.genero  cliente.idoso cliente.parceiro  \
# 30    0047-ZHDTW             feminino              0              nao
# 75    0120-YZLQA            masculino              0              nao
# 96    0154-QYHJU            masculino              0              nao
# 98    0162-RZGMZ             feminino              1              nao
# 175   0274-VVQOQ            masculino              1              sim
# ...          ...   ...            ...            ...              ...
# 7211  9920-GNDMB            masculino              0              nao
# 7239  9955-RVWSC             feminino              0              sim
# 7247  9966-VYRTZ             feminino              0              sim
# 7267  6532-YOHZY            masculino              0              sim
# 7342  3601-UTZXO            masculino              0              sim
#
#      cliente.dependentes  cliente.tempo_servico telefone.servico_telefone  \
# ...

# %%
dados_sem_vazio = dados_normalizados[dados_normalizados['Churn'] != ''].copy()

# %%
dados_sem_vazio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7118 entries, 0 to 7343
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id_cliente                     7118 non-null   object
#  1   Churn                          7118 non-null   object
#  2   cliente.genero                 7118 non-null   object
#  3   cliente.idoso                  7118 non-null   int64
#  4   cliente.parceiro               7118 non-null   object
#  5   cliente.dependentes            7118 non-null   object
#  6   cliente.tempo_servico          7110 non-null   float64
#  7   telefone.servico_telefone      7118 non-null   object
#  8   telefone.varias_linhas         7118 non-null   object
#  9   internet.servico_internet      7118 non-null   object
#  10  internet.seguranca_online      7118 non-null   object
#  11  internet.backup_online         7118 non-null   object
# ...

# %%
dados_sem_vazio.reset_index(drop=True, inplace=True)

# %%
dados_sem_vazio
# Out:
#       id_cliente Churn cliente.genero  cliente.idoso cliente.parceiro  \
# 0     0002-ORFBO   nao       feminino              0              sim
# 1     0003-MKNFE   nao      masculino              0              nao
# 2     0004-TLHLJ   sim      masculino              0              nao
# 3     0011-IGKFF   sim      masculino              1              sim
# 4     0013-EXCHZ   sim       feminino              1              sim
# ...          ...   ...            ...            ...              ...
# 7113  5792-JALQC   nao       feminino              1              nao
# 7114  5172-RKOCB   nao      masculino              0              sim
# 7115  1934-MKPXS   nao      masculino              0              sim
# 7116  5959-BELXA   sim      masculino              1              nao
# 7117  4452-QIIEB   nao      masculino              0              nao
#
#      cliente.dependentes  cliente.tempo_servico telefone.servico_telefone  \
# ...

# %%
dados_sem_vazio.duplicated().sum()
# Out:
# np.int64(75)

# %%
duplicados = dados_sem_vazio.duplicated()

# %%
dados_sem_vazio.drop_duplicates(inplace=True)

# %%
dados_sem_vazio.duplicated().sum()
# Out:
# np.int64(0)

# %%
dados_sem_vazio.isna()
# Out:
#       id_cliente  Churn  cliente.genero  cliente.idoso  cliente.parceiro  \
# 0          False  False           False          False             False
# 1          False  False           False          False             False
# 2          False  False           False          False             False
# 3          False  False           False          False             False
# 4          False  False           False          False             False
# ...          ...    ...             ...            ...               ...
# 7038       False  False           False          False             False
# 7039       False  False           False          False             False
# 7040       False  False           False          False             False
# 7041       False  False           False          False             False
# 7042       False  False           False          False             False
#
#       cliente.dependentes  cliente.tempo_servico  telefone.servico_telefone  \
# ...

# %%
dados_sem_vazio[dados_sem_vazio.isna().any(axis=1)]
# Out:
#       id_cliente Churn cliente.genero  cliente.idoso cliente.parceiro  \
# 0     0002-ORFBO   nao       feminino              0              sim
# 9     0016-QLJIS   nao       feminino              0              sim
# 176   0282-NVSJS   nao       feminino              1              sim
# 181   0295-QVKPB   nao      masculino              0              nao
# 437   0639-TSIQW   sim       feminino              0              nao
# 751   1095-WGNGG   nao       feminino              0              sim
# 963   1396-QWFBJ   sim       feminino              0              sim
# 1604  2333-KWEWW   nao      masculino              0              nao
# 1605  2335-GSODA   nao      masculino              0              nao
# 1606  2338-BQEZT   nao       feminino              0              nao
# 1608  2344-JMOGN   sim      masculino              0              sim
# 2036  2931-FSOHN   nao      masculino              1              nao
# ...

# %%
filtro = dados_sem_vazio['cliente.tempo_servico'].isna()

# %%
dados_sem_vazio[filtro][['cliente.tempo_servico', 'conta.cobranca.mensal', 'conta.cobranca.Total']]
# Out:
#       cliente.tempo_servico  conta.cobranca.mensal  conta.cobranca.Total
# 9                       NaN                  90.45               5957.90
# 176                     NaN                  29.30                355.90
# 181                     NaN                  63.95                318.10
# 751                     NaN                 101.05               5971.25
# 3523                    NaN                  76.10               1054.80
# 5273                    NaN                  20.60                116.60
# 5276                    NaN                  73.85               3581.40
# 6134                    NaN                  69.05               1958.45

# %%
dados_sem_vazio['cliente.tempo_servico'].fillna(
    np.ceil(
        dados_sem_vazio['conta.cobranca.Total'] / dados_sem_vazio['conta.cobranca.mensal']
    ),
    inplace=True
)
# Out:
# C:\Users\raphael.gaias.TACLA\AppData\Local\Temp\ipykernel_5500\4277841043.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dados_sem_vazio['cliente.tempo_servico'].fillna(

# %%
dados_sem_vazio[filtro][['cliente.tempo_servico', 'conta.cobranca.mensal', 'conta.cobranca.Total']]
# Out:
#       cliente.tempo_servico  conta.cobranca.mensal  conta.cobranca.Total
# 9                      66.0                  90.45               5957.90
# 176                    13.0                  29.30                355.90
# 181                     5.0                  63.95                318.10
# 751                    60.0                 101.05               5971.25
# 3523                   14.0                  76.10               1054.80
# 5273                    6.0                  20.60                116.60
# 5276                   49.0                  73.85               3581.40
# 6134                   29.0                  69.05               1958.45

# %%
colunas_dropar = ['conta.contrato', 'conta.faturamente_eletronico', 'conta.metodo_pagamento']

# %%
dados_sem_vazio[colunas_dropar].isna().any(axis=1).sum()
# Out:
# np.int64(37)

# %%
dados_sem_vazio.dropna (subset=colunas_dropar)
# Out:
#       id_cliente Churn cliente.genero  cliente.idoso cliente.parceiro  \
# 1     0003-MKNFE   nao      masculino              0              nao
# 2     0004-TLHLJ   sim      masculino              0              nao
# 3     0011-IGKFF   sim      masculino              1              sim
# 4     0013-EXCHZ   sim       feminino              1              sim
# 5     0013-MHZWF   nao       feminino              0              nao
# ...          ...   ...            ...            ...              ...
# 7038  9987-LUTYD   nao       feminino              0              nao
# 7039  9992-RRAMN   sim      masculino              0              sim
# 7040  9992-UJOEL   nao      masculino              0              nao
# 7041  9993-LHIEB   nao      masculino              0              sim
# 7042  9995-HOTOH   nao      masculino              0              sim
#
#      cliente.dependentes  cliente.tempo_servico telefone.servico_telefone  \
# ...

# %%
df_sem_nulo = dados_sem_vazio.dropna (subset=colunas_dropar).copy().reset_index(drop=True)

# %%
df_sem_nulo.head()
# Out:
#    id_cliente Churn cliente.genero  cliente.idoso cliente.parceiro  \
# 0  0003-MKNFE   nao      masculino              0              nao
# 1  0004-TLHLJ   sim      masculino              0              nao
# 2  0011-IGKFF   sim      masculino              1              sim
# 3  0013-EXCHZ   sim       feminino              1              sim
# 4  0013-MHZWF   nao       feminino              0              nao
#
#   cliente.dependentes  cliente.tempo_servico telefone.servico_telefone  \
# 0                 nao                    9.0                       sim
# 1                 nao                    4.0                       sim
# 2                 nao                   13.0                       sim
# 3                 nao                    3.0                       sim
# 4                 sim                    9.0                       sim
#
#   telefone.varias_linhas internet.servico_internet  ...  \
# 0                    sim                       DSL  ...
# ...

# %% [markdown]
# DESAFIO

# %%
with open ('cursos_cadastrados.json') as f:
    json_bruto = json.load(f)

json_bruto
# Out:
# [{'curso': 'IntroduÃ§Ã£o Ã\xa0 programaÃ§Ã£o',
#   'categoria': 'ProgramaÃ§Ã£o',
#   'carga_horaria': '20 horas',
#   'concluintes': 100,
#   'data_inicio': '2022-01-01',
#   'data_conclusao': '2022-01-20',
#   'descricao': 'Curso introdutÃ³rio Ã\xa0 programaÃ§Ã£o com Python',
#   'preco': '99.90',
#   'instrutor': {'nome': 'JoÃ£o Silva',
#    'email': 'joao.silva@emailaleatorio.com',
#    'telefone': '(11) 9999-9999'}},
#  {'curso': 'Excel para iniciantes',
#   'categoria': 'Produtividade',
#   'carga_horaria': None,
#   'concluintes': None,
#   'data_inicio': None,
#   'data_conclusao': None,
#   'descricao': None,
#   'preco': None,
#   'instrutor': {'nome': 'Maria Oliveira',
#    'email': 'maria.oliveira@emailaleatorio.com',
#    'telefone': '(11) 8888-8888'}},
#  {'curso': 'Marketing digital para negÃ³cios',
#   'categoria': 'Marketing',
#   'carga_horaria': '30 horas',
#   'concluintes': 75,
#   'data_inicio': '2022-03-01',
#   'data_conclusao': '2022-03-31',
# ...

# %%
df_cursos = pd.json_normalize (json_bruto)

# %%
df_cursos.isna().sum()
# Out:
# curso                 0
# categoria             0
# carga_horaria         1
# concluintes           1
# data_inicio           1
# data_conclusao        1
# descricao             1
# preco                 1
# instrutor.nome        0
# instrutor.email       0
# instrutor.telefone    0
# dtype: int64

# %%
df_cursos.dropna(axis=0, inplace=True)

# %%
df_cursos
# Out:
#                               curso      categoria carga_horaria concluintes  \
# 0     IntroduÃ§Ã£o Ã  programaÃ§Ã£o  ProgramaÃ§Ã£o      20 horas         100
# 2  Marketing digital para negÃ³cios      Marketing      30 horas          75
# 3          InteligÃªncia artificial  ProgramaÃ§Ã£o      40 horas
# 4            InglÃªs para negÃ³cios        Idiomas      20 horas          30
# 5     IntroduÃ§Ã£o Ã  programaÃ§Ã£o  ProgramaÃ§Ã£o      20 horas         100
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 2  2022-03-01     2022-03-31
# 3  2022-04-01
# 4
# 5  2022-01-01     2022-01-20
#
#                                            descricao  preco instrutor.nome  \
# 0    Curso introdutÃ³rio Ã  programaÃ§Ã£o com Python  99.90    JoÃ£o Silva
# 2                   Curso introdutÃ³rio em marketing   89.9     Ana Santos
# 3  Curso avanÃ§ado sobre inteligÃªncia artificial...  129.9
# 4                    Curso de inglÃªs para negÃ³cios   69.9     John Smith
# ...

# %%
colunas = df_cursos.columns
colunas
# Out:
# Index(['curso', 'categoria', 'carga_horaria', 'concluintes', 'data_inicio',
#        'data_conclusao', 'descricao', 'preco', 'instrutor.nome',
#        'instrutor.email', 'instrutor.telefone'],
#       dtype='object')

# %%
df_cursos = df_cursos.dropna (subset=colunas).reset_index(drop=True)
df_cursos
# Out:
#                               curso      categoria carga_horaria concluintes  \
# 0     IntroduÃ§Ã£o Ã  programaÃ§Ã£o  ProgramaÃ§Ã£o      20 horas         100
# 1  Marketing digital para negÃ³cios      Marketing      30 horas          75
# 2          InteligÃªncia artificial  ProgramaÃ§Ã£o      40 horas
# 3            InglÃªs para negÃ³cios        Idiomas      20 horas          30
# 4     IntroduÃ§Ã£o Ã  programaÃ§Ã£o  ProgramaÃ§Ã£o      20 horas         100
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 1  2022-03-01     2022-03-31
# 2  2022-04-01
# 3
# 4  2022-01-01     2022-01-20
#
#                                            descricao  preco instrutor.nome  \
# 0    Curso introdutÃ³rio Ã  programaÃ§Ã£o com Python  99.90    JoÃ£o Silva
# 1                   Curso introdutÃ³rio em marketing   89.9     Ana Santos
# 2  Curso avanÃ§ado sobre inteligÃªncia artificial...  129.9
# 3                    Curso de inglÃªs para negÃ³cios   69.9     John Smith
# ...

# %%
df_cursos.isna().any(axis=1).sum()
# Out:
# np.int64(0)

# %%
df_cursos = df_cursos[df_cursos[colunas] != ''].copy()

# %%
df_cursos
# Out:
#                               curso      categoria carga_horaria concluintes  \
# 0     IntroduÃ§Ã£o Ã  programaÃ§Ã£o  ProgramaÃ§Ã£o      20 horas         100
# 1  Marketing digital para negÃ³cios      Marketing      30 horas          75
# 2          InteligÃªncia artificial  ProgramaÃ§Ã£o      40 horas         NaN
# 3            InglÃªs para negÃ³cios        Idiomas      20 horas          30
# 4     IntroduÃ§Ã£o Ã  programaÃ§Ã£o  ProgramaÃ§Ã£o      20 horas         100
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 1  2022-03-01     2022-03-31
# 2  2022-04-01            NaN
# 3         NaN            NaN
# 4  2022-01-01     2022-01-20
#
#                                            descricao  preco instrutor.nome  \
# 0    Curso introdutÃ³rio Ã  programaÃ§Ã£o com Python  99.90    JoÃ£o Silva
# 1                   Curso introdutÃ³rio em marketing   89.9     Ana Santos
# 2  Curso avanÃ§ado sobre inteligÃªncia artificial...  129.9            NaN
# ...

# %%
df_cursos.dropna(inplace=True)
df_cursos
# Out:
#                               curso      categoria carga_horaria concluintes  \
# 0     IntroduÃ§Ã£o Ã  programaÃ§Ã£o  ProgramaÃ§Ã£o      20 horas         100
# 1  Marketing digital para negÃ³cios      Marketing      30 horas          75
# 4     IntroduÃ§Ã£o Ã  programaÃ§Ã£o  ProgramaÃ§Ã£o      20 horas         100
#
#   data_inicio data_conclusao                                        descricao  \
# 0  2022-01-01     2022-01-20  Curso introdutÃ³rio Ã  programaÃ§Ã£o com Python
# 1  2022-03-01     2022-03-31                 Curso introdutÃ³rio em marketing
# 4  2022-01-01     2022-01-20  Curso introdutÃ³rio Ã  programaÃ§Ã£o com Python
#
#    preco instrutor.nome                instrutor.email instrutor.telefone
# 0  99.90    JoÃ£o Silva  joao.silva@emailaleatorio.com     (11) 9999-9999
# 1   89.9     Ana Santos  ana.santos@emailaleatorio.com     (11) 7777-7777
# 4  99.90    JoÃ£o Silva  joao.silva@emailaleatorio.com     (11) 9999-9999

# %%
df_cursos.drop_duplicates(inplace=True)
df_cursos
# Out:
#                               curso      categoria carga_horaria concluintes  \
# 0     IntroduÃ§Ã£o Ã  programaÃ§Ã£o  ProgramaÃ§Ã£o      20 horas         100
# 1  Marketing digital para negÃ³cios      Marketing      30 horas          75
#
#   data_inicio data_conclusao                                        descricao  \
# 0  2022-01-01     2022-01-20  Curso introdutÃ³rio Ã  programaÃ§Ã£o com Python
# 1  2022-03-01     2022-03-31                 Curso introdutÃ³rio em marketing
#
#    preco instrutor.nome                instrutor.email instrutor.telefone
# 0  99.90    JoÃ£o Silva  joao.silva@emailaleatorio.com     (11) 9999-9999
# 1   89.9     Ana Santos  ana.santos@emailaleatorio.com     (11) 7777-7777

# %%
df_cursos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 0 to 1
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   curso               2 non-null      object
#  1   categoria           2 non-null      object
#  2   carga_horaria       2 non-null      object
#  3   concluintes         2 non-null      object
#  4   data_inicio         2 non-null      object
#  5   data_conclusao      2 non-null      object
#  6   descricao           2 non-null      object
#  7   preco               2 non-null      object
#  8   instrutor.nome      2 non-null      object
#  9   instrutor.email     2 non-null      object
#  10  instrutor.telefone  2 non-null      object
# dtypes: object(11)
# memory usage: 192.0+ bytes

# %%
df_cursos['data_conclusao'] = pd.to_datetime (df_cursos['data_conclusao'])
df_cursos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 0 to 1
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   curso               2 non-null      object
#  1   categoria           2 non-null      object
#  2   carga_horaria       2 non-null      object
#  3   concluintes         2 non-null      object
#  4   data_inicio         2 non-null      object
#  5   data_conclusao      2 non-null      datetime64[ns]
#  6   descricao           2 non-null      object
#  7   preco               2 non-null      object
#  8   instrutor.nome      2 non-null      object
#  9   instrutor.email     2 non-null      object
#  10  instrutor.telefone  2 non-null      object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 192.0+ bytes

# %% [markdown]
# DESAFIO ✅

# %%
df_sem_nulo.describe()
# Out:
#        cliente.idoso  cliente.tempo_servico  conta.cobranca.mensal  \
# count    7006.000000            7006.000000            7006.000000
# mean        0.162004              33.286183              64.720361
# std         0.368481              35.311206              30.084664
# min         0.000000               1.000000              18.250000
# 25%         0.000000               9.000000              35.450000
# 50%         0.000000              29.000000              70.300000
# 75%         0.000000              56.000000              89.850000
# max         1.000000            1080.000000             118.750000
#
#        conta.cobranca.Total
# count           7006.000000
# mean            2317.743862
# std             2876.919022
# min               18.800000
# 25%              402.087500
# 50%             1392.925000
# 75%             3783.600000
# max           112212.000000

# %%
sns.boxplot (x=df_sem_nulo['cliente.tempo_servico'])
# Out:
# <Axes: xlabel='cliente.tempo_servico'>

# %%
q1 = df_sem_nulo['cliente.tempo_servico'].quantile(.25)
q3 = df_sem_nulo['cliente.tempo_servico'].quantile(.75)
iqr = q3 - q1
limite_inf = q1 - 1.5 * iqr
limite_sup = q3 + 1.5 * iqr

# %%
outliers_idx = (df_sem_nulo['cliente.tempo_servico'] < limite_inf) | (df_sem_nulo['cliente.tempo_servico'] > limite_sup)
outliers_idx
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7001    False
# 7002    False
# 7003    False
# 7004    False
# 7005    False
# Name: cliente.tempo_servico, Length: 7006, dtype: bool

# %%
df_sem_nulo[outliers_idx]['cliente.tempo_servico']
# Out:
# 1945    1080.0
# 1946    1000.0
# 1952     950.0
# 1956     254.0
# 1958     321.0
# 1963     650.0
# 1966     721.0
# 1970     555.0
# 1973     433.0
# 1974     512.0
# Name: cliente.tempo_servico, dtype: float64

# %% [markdown]
# Corrigindo Outliers

# %%
df_sem_out = df_sem_nulo.copy()

# %%
df_sem_out.loc[outliers_idx, 'cliente.tempo_servico'] = np.ceil(
    df_sem_out.loc[outliers_idx, 'conta.cobranca.Total'] / 
    df_sem_out.loc[outliers_idx, 'conta.cobranca.mensal']
)

# %%
sns.boxplot (x=df_sem_out['cliente.tempo_servico'])
# Out:
# <Axes: xlabel='cliente.tempo_servico'>

# %%
df_sem_nulo[outliers_idx][['cliente.tempo_servico', 'conta.cobranca.mensal', 'conta.cobranca.Total']]
# Out:
#       cliente.tempo_servico  conta.cobranca.mensal  conta.cobranca.Total
# 1945                 1080.0                 103.90             112212.00
# 1946                 1000.0                  45.90              45900.00
# 1952                  950.0                  84.10              79895.00
# 1956                  254.0                  46.05                 80.35
# 1958                  321.0                  99.80               4259.30
# 1963                  650.0                  73.00              47450.00
# 1966                  721.0                  89.55               3856.75
# 1970                  555.0                  19.15                124.40
# 1973                  433.0                  89.20                346.20
# 1974                  512.0                  19.55                 19.55
